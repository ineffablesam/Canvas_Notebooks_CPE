# %% [markdown]
# # Module 5 · Lesson 1 Word-Problem Lab
# ## Variables, Data Types, and Lists
#
# ![Inventory Quest: organize Python values before the clock runs out.](attachment:m5_l1_inventory_quest.jpg)
#
# > **ARCADE MISSION:** Inventory Quest: organize Python values before the clock runs out.
#
# This notebook matches the lesson-page concept: **Store values, inspect their types, and organize related values in collections.**
#
# This is a short, self-contained challenge. It does **not** edit the cumulative
# **Will They Show Up?** project. You will transfer the lesson skill at the separate Model Build Checkpoint.
#
# Use this rhythm: **Accept mission → Predict → Run → Remix → Explain → Verify.**
#
# **Win condition:** finish with working code, one visible piece of evidence, and an explanation
# that a non-programmer could understand.

# %% [markdown]
# ## 1. Challenge briefing
#
# You have opened a fantasy inventory chest containing crystals, tools, and mystery items. The inventory system must store names, quantities, and item categories without mixing them up.
#
# ### Decision to make
#
# **How should the loot be stored so another player can retrieve, count, and update it reliably?**
#
# ### Your deliverable
#
# Change one inventory item, add a numeric quantity, print its type, and explain why a list is more useful than three unrelated variables.

# %% [markdown]
# ## 2. Predict before Python
#
# Predict the type and output of each value before running the cell.
#
# Write a specific prediction and one reason. “I don’t know” is allowed only if you also identify
# the exact line or concept you need to inspect.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+WORKED+EXAMPLE%0A%23+Read+the+word+problem+first+and+predict+the+result+before+running+this+cell.%0A%23+Every+printed+value+is+evidence+you+can+cite+in+your+explanation.%0A%0Astudent+%3D+%22Maya%22%0Apractice_minutes+%3D+25%0Atopics+%3D+%5B%22variables%22%2C+%22types%22%2C+%22lists%22%5D%0Aprint%28student%2C+type%28student%29.__name__%29%0Aprint%28practice_minutes%2C+type%28practice_minutes%29.__name__%29%0Aprint%28topics%5B0%5D%2C+len%28topics%29%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# WORKED EXAMPLE
# Read the word problem first and predict the result before running this cell.
# Every printed value is evidence you can cite in your explanation.

student = "Maya"
practice_minutes = 25
topics = ["variables", "types", "lists"]
print(student, type(student).__name__)
print(practice_minutes, type(practice_minutes).__name__)
print(topics[0], len(topics))

# %% [markdown]
# ## 3. Read the evidence
#
# Before changing the code, explain:
#
# 1. What information went in?
# 2. Which lesson concept transformed or evaluated it?
# 3. What visible output came out?
# 4. How does that output help answer the challenge decision?
# 5. What assumption or limitation remains?
#
# Use exact variable names or output values as evidence.

# %% [markdown]
# ## 4. Solve the word problem
#
# Change one inventory item, add a numeric quantity, print its type, and explain why a list is more useful than three unrelated variables.
#
# Keep your changed code and output. Your explanation should answer the decision—not merely say
# that the code “worked.”

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+YOUR+WORD-PROBLEM+INVESTIGATION%0A%23+Mission%3A+Change+one+inventory+item%2C+add+a+numeric+quantity%2C+print+its+type%2C+and+explain+why+a+list+is+more+useful+than+three+unrelated+variables.%0A%23+Change+one+thing+at+a+time%2C+rerun%2C+and+keep+the+output+that+supports+your+answer.%0A%0Aplaylist+%3D+%5B%22focus%22%2C+%22review%22%2C+%22challenge%22%5D%0Aplaylist.append%28%22reflect%22%29%0Afirst_item+%3D+playlist%5B0%5D%0Aprint%28%22Updated+list%3A%22%2C+playlist%29%0Aprint%28%22First+item%3A%22%2C+first_item%29%0A%23+Practice%3A+replace+one+item%2C+add+a+number+variable%2C+and+print+its+type."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# YOUR WORD-PROBLEM INVESTIGATION
# Mission: Change one inventory item, add a numeric quantity, print its type, and explain why a list is more useful than three unrelated variables.
# Change one thing at a time, rerun, and keep the output that supports your answer.

playlist = ["focus", "review", "challenge"]
playlist.append("reflect")
first_item = playlist[0]
print("Updated list:", playlist)
print("First item:", first_item)
# Practice: replace one item, add a number variable, and print its type.

# %% [markdown]
# ## Bonus round: Remix the challenge
#
# Choose **one** remix—small enough to test in under five minutes:
#
# - **Twist the input:** add one realistic normal case and predict its result.
# - **Break it safely:** add one edge case that might expose a weak assumption.
# - **Make it yours:** rename the fictional objects or values while preserving the lesson concept.
#
# Write your prediction first. Then use the code cell below to run the remix and record what changed.
# Your remix should still help answer this mission: **Change one inventory item, add a numeric quantity, print its type, and explain why a list is more useful than three unrelated variables.**

# %%
# BONUS ROUND WORKSPACE
# Copy only the smallest relevant part of the investigation here.
# 1. State your prediction in a comment.
# 2. Change one thing.
# 3. Print or assert the evidence.

# Your remix:
pass

# %% [markdown]
# ## 5. Verify your solution
#
# - Did you change only what the mission requested?
# - Can another person reproduce the output by running from the top?
# - Does your written answer cite a printed value, row, prediction, or test?
# - Did you distinguish what the evidence supports from what it cannot prove?
#
# <details>
# <summary><strong>Reveal one strong-answer approach</strong></summary>
#
# A strong answer updates the list by position or with append(), stores the number as an int or float, and connects the chosen type to what the value represents.
#
# </details>

# %% [markdown]
# ## 6. Optional AI helper—with verification
#
# If you are stuck, ask Gemini or another approved assistant:
#
# > I am solving a beginner Python word problem about **Variables, Data Types, and Lists**. Explain the next step
# > without replacing my whole solution. Name the exact line I should inspect and give me one
# > small test I can run.
#
# Then record:
#
# - the assistant’s claim;
# - the test you ran;
# - whether the output supported, corrected, or contradicted the claim.
#
# Never upload personal or confidential data. This notebook uses only tiny fictional examples.

# %% [markdown]
# ## 7. Exit ticket
#
# In 2–4 sentences:
#
# 1. Answer the campus decision.
# 2. Cite the strongest output evidence.
# 3. Name one limit or next check.
#
# **Achievement unlocked when:** your answer cites visible output and survives one remix or edge-case test.
#
# Save this lesson-practice notebook separately. Do not paste it into the cumulative project.
