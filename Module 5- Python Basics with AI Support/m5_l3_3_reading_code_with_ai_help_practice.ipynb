# %% [markdown]
# # Module 5 · Lesson 3 Word-Problem Lab
# ## Reading Code with AI Help
#
# ![AI Detective Trial: test every explanation against the code.](attachment:m5_l3_ai_detective_trial.jpg)
#
# > **ARCADE MISSION:** AI Detective Trial: test every explanation against the code.
#
# This notebook matches the lesson-page concept: **Trace code yourself, then check an AI-style explanation against evidence.**
#
# This is a short, self-contained challenge. It does **not** edit the cumulative
# **Will They Show Up?** project. You will transfer the lesson skill at the separate Model Build Checkpoint.
#
# Use this rhythm: **Accept mission → Predict → Run → Remix → Explain → Verify.**
#
# **Win condition:** finish with working code, one visible piece of evidence, and an explanation
# that a non-programmer could understand.

# %% [markdown]
# ## 1. Challenge briefing
#
# An AI detective claims it has decoded a label-cleaning function from a digital evidence file. The claim cannot enter the case record until it matches the code and output.
#
# ### Decision to make
#
# **Which parts of the AI-style explanation are supported by visible execution evidence?**
#
# ### Your deliverable
#
# Add one accurate claim about the list comprehension and one deliberately false claim that a classmate could catch by testing.

# %% [markdown]
# ## 2. Predict before Python
#
# Read the function line by line and write the expected output first.
#
# Write a specific prediction and one reason. “I don’t know” is allowed only if you also identify
# the exact line or concept you need to inspect.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+WORKED+EXAMPLE%0A%23+Read+the+word+problem+first+and+predict+the+result+before+running+this+cell.%0A%23+Every+printed+value+is+evidence+you+can+cite+in+your+explanation.%0A%0Adef+normalize_label%28label%29%3A%0A++++cleaned+%3D+label.strip%28%29.lower%28%29%0A++++return+cleaned.replace%28%22+%22%2C+%22_%22%29%0A%0Alabels+%3D+%5B%22++Needs+Review+%22%2C+%22Ready+Now%22%5D%0Aresult+%3D+%5Bnormalize_label%28label%29+for+label+in+labels%5D%0Aprint%28result%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# WORKED EXAMPLE
# Read the word problem first and predict the result before running this cell.
# Every printed value is evidence you can cite in your explanation.

def normalize_label(label):
    cleaned = label.strip().lower()
    return cleaned.replace(" ", "_")

labels = ["  Needs Review ", "Ready Now"]
result = [normalize_label(label) for label in labels]
print(result)

# %% [markdown]
# ## 3. Read the evidence
#
# Before changing the code, explain:
#
# 1. What information went in?
# 2. Which lesson concept transformed or evaluated it?
# 3. What visible output came out?
# 4. How does that output help answer the challenge decision?
# 5. What assumption or limitation remains?
#
# Use exact variable names or output values as evidence.

# %% [markdown]
# ## 4. Solve the word problem
#
# Add one accurate claim about the list comprehension and one deliberately false claim that a classmate could catch by testing.
#
# Keep your changed code and output. Your explanation should answer the decision—not merely say
# that the code “worked.”

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+YOUR+WORD-PROBLEM+INVESTIGATION%0A%23+Mission%3A+Add+one+accurate+claim+about+the+list+comprehension+and+one+deliberately+false+claim+that+a+classmate+could+catch+by+testing.%0A%23+Change+one+thing+at+a+time%2C+rerun%2C+and+keep+the+output+that+supports+your+answer.%0A%0Aclaims+%3D+%7B%0A++++%22strip+removes+outside+spaces%22%3A+True%2C%0A++++%22lower+changes+letters+to+lowercase%22%3A+True%2C%0A++++%22replace+deletes+every+underscore%22%3A+False%2C%0A%7D%0Afor+claim%2C+supported+in+claims.items%28%29%3A%0A++++print%28%22SUPPORTED%22+if+supported+else+%22CORRECT+THIS%22%2C+%22-%22%2C+claim%29%0A%23+Practice%3A+add+one+accurate+claim+about+the+list+comprehension."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# YOUR WORD-PROBLEM INVESTIGATION
# Mission: Add one accurate claim about the list comprehension and one deliberately false claim that a classmate could catch by testing.
# Change one thing at a time, rerun, and keep the output that supports your answer.

claims = {
    "strip removes outside spaces": True,
    "lower changes letters to lowercase": True,
    "replace deletes every underscore": False,
}
for claim, supported in claims.items():
    print("SUPPORTED" if supported else "CORRECT THIS", "-", claim)
# Practice: add one accurate claim about the list comprehension.

# %% [markdown]
# ## Bonus round: Remix the challenge
#
# Choose **one** remix—small enough to test in under five minutes:
#
# - **Twist the input:** add one realistic normal case and predict its result.
# - **Break it safely:** add one edge case that might expose a weak assumption.
# - **Make it yours:** rename the fictional objects or values while preserving the lesson concept.
#
# Write your prediction first. Then use the code cell below to run the remix and record what changed.
# Your remix should still help answer this mission: **Add one accurate claim about the list comprehension and one deliberately false claim that a classmate could catch by testing.**

# %%
# BONUS ROUND WORKSPACE
# Copy only the smallest relevant part of the investigation here.
# 1. State your prediction in a comment.
# 2. Change one thing.
# 3. Print or assert the evidence.

# Your remix:
pass

# %% [markdown]
# ## 5. Verify your solution
#
# - Did you change only what the mission requested?
# - Can another person reproduce the output by running from the top?
# - Does your written answer cite a printed value, row, prediction, or test?
# - Did you distinguish what the evidence supports from what it cannot prove?
#
# <details>
# <summary><strong>Reveal one strong-answer approach</strong></summary>
#
# A strong answer traces strip(), lower(), replace(), and the repeated function call separately, then cites the printed list as evidence.
#
# </details>

# %% [markdown]
# ## 6. Optional AI helper—with verification
#
# If you are stuck, ask Gemini or another approved assistant:
#
# > I am solving a beginner Python word problem about **Reading Code with AI Help**. Explain the next step
# > without replacing my whole solution. Name the exact line I should inspect and give me one
# > small test I can run.
#
# Then record:
#
# - the assistant’s claim;
# - the test you ran;
# - whether the output supported, corrected, or contradicted the claim.
#
# Never upload personal or confidential data. This notebook uses only tiny fictional examples.

# %% [markdown]
# ## 7. Exit ticket
#
# In 2–4 sentences:
#
# 1. Answer the campus decision.
# 2. Cite the strongest output evidence.
# 3. Name one limit or next check.
#
# **Achievement unlocked when:** your answer cites visible output and survives one remix or edge-case test.
#
# Save this lesson-practice notebook separately. Do not paste it into the cumulative project.
