# %% [markdown]
# # Will They Show Up? · Module 5
#
# This notebook begins **Will They Show Up?**, the project you will build through Module 9. No earlier project file is required.
#
# ## Part 1 mission
#
# **Question:** Can transparent Python rules inspect a few event proposals consistently?
#
# **Build:** Build and test a rule-based Event Inspector with collections, conditions, loops, and functions.
#
# **Save:** A working inspector plus evidence that you tested normal and edge cases.

# %%
# Out:
# <Embedded Module 5 checkpoint visual>

# %% [markdown]
# ## Start
#
# - This notebook only. Part 1 uses event examples already stored inside it.
#
# 1. Open in Colab and choose **File → Save a copy in Drive**.
# 2. Run cells from top to bottom.
# No file upload is needed for Part 1.
#
# All records are synthetic. If Colab resets, upload the CSV files again.

# %% [markdown]
# ---
#
# # Part 1 · Begin the project here
#
# Run this first project section in order. Each step prepares the next one.

# %% [markdown]
# # Will They Show Up? · Checkpoint 1
# ## Build a Transparent Event Inspector
#
# **Module 5 contribution:** Use variables, dictionaries, lists, conditions, loops, functions, and tests to build a human-written rule. This tool does not learn from data.
#
# **Driving question:** If a person writes every scoring rule, what can the program do—and what can it not prove?

# %% [markdown]
# ## Mission
#
# Three fictional campus events need a first review. Build a function that applies the same visible rules to each proposal. Predict the labels before coding.
#
# > **Your prediction:** Which event will receive the highest score, and why?
# >
# > **Write here before running:**

# %% [markdown]
# <details>
# <summary><strong>Reveal model answer</strong></summary>
#
# Use this to check your reasoning after you have written your own response.
#
# **Reference answer:** Friday Game Night should score highest with 5 points:
# weekend timing (2), after-school start (1), free admission (1), and at least seven
# promotion days (1). Saturday Film Night scores 4 because it misses the promotion rule.
# Monday Sunrise Talk scores 0.
#
# </details>

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="https://stevens.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=83fd0fd0-a4ab-42d7-bb4b-b49c00e91abb"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a></td></tr></table>

# %%
# TASK: Create three fictional event proposals using dictionaries inside a list.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Confirm that every proposal has the same five fields; later cells depend on those exact names.

event_proposals = [
    {"event_name": "Friday Game Night", "day_of_week": "Friday", "start_hour": 18, "free_event": True, "promotion_days": 10},
    {"event_name": "Monday Sunrise Talk", "day_of_week": "Monday", "start_hour": 7, "free_event": False, "promotion_days": 1},
    {"event_name": "Saturday Film Night", "day_of_week": "Saturday", "start_hour": 19, "free_event": True, "promotion_days": 4},
]

for event in event_proposals:
    print(event)

# %% [markdown]
# ## Inspect the information structures
#
# Use the event data to practice the Module 5 collection choices:
#
# - A **list** keeps event records in order and can change.
# - A **tuple** stores a fixed field order.
# - A **set** keeps unique values.
# - A **dictionary** connects field names with one event's values.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="https://stevens.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=4dceceae-8960-4d9e-961b-b49c00e9c551"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a></td></tr></table>

# %%
# TASK: Demonstrate a tuple for fixed field order, a set for unique weekdays, and a dictionary lookup.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Compare what each collection preserves: order, uniqueness, or key-to-value meaning.

fixed_field_order = ("event_name", "day_of_week", "start_hour", "free_event", "promotion_days")
unique_days = {event["day_of_week"] for event in event_proposals}
first_event = event_proposals[0]

print("List length:", len(event_proposals), type(event_proposals).__name__)
print("Fixed tuple:", fixed_field_order, type(fixed_field_order).__name__)
print("Unique-day set:", unique_days, type(unique_days).__name__)
print("One dictionary:", first_event, type(first_event).__name__)

# Explain why each collection fits its job. Then add one safe field to first_event.

# %% [markdown]
# ## Build the rule
#
# Complete every `TODO`. Do not ask Gemini for a complete replacement.

# %%
# TASK: Define the transparent rule-based Event Inspector used before machine learning.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Trace each condition and verify that the returned score, label, and reasons agree with one another.

def inspect_event(event):
    score = 0
    reasons = []

    # TODO 1: Add 2 points for Friday or Saturday.
    # TODO 2: Add 1 point for a start hour of 17, 18, or 19.
    # TODO 3: Add 1 point when free_event is True.
    # TODO 4: Add 1 point for at least 7 promotion days.
    # Every added point needs a short reason.

    # TODO 5: Use if/elif/else:
    # 4+ = "promising", 2–3 = "possible", below 2 = "needs review".
    label = ""
    return {"label": label, "score": score, "reasons": reasons}

# %% [markdown]
# <details>
# <summary><strong>Reveal reference solution</strong></summary>
#
# Use this after making a genuine attempt. Compare the approach with your own work;
# more than one correct solution may exist.
#
# ```python
# # TASK: Define the transparent rule-based Event Inspector used before machine learning.
# # WHY: This code creates evidence used by this checkpoint and the next project stage.
# # CHECK: Trace each condition and verify that the returned score, label, and reasons agree with one another.
#
# def inspect_event(event):
#     score = 0
#     reasons = []
#
#     if event.get("day_of_week") in ["Friday", "Saturday"]:
#         score += 2
#         reasons.append("weekend timing")
#     if event.get("start_hour") in [17, 18, 19]:
#         score += 1
#         reasons.append("after-school start")
#     if event.get("free_event") is True:
#         score += 1
#         reasons.append("free admission")
#     if event.get("promotion_days", 0) >= 7:
#         score += 1
#         reasons.append("at least one week of promotion")
#
#     if score >= 4:
#         label = "promising"
#     elif score >= 2:
#         label = "possible"
#     else:
#         label = "needs review"
#     return {"label": label, "score": score, "reasons": reasons}
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary><strong>Hints</strong></summary>
#
# - Use `event.get("field_name")` to read a value safely.
# - A condition can add points and append a reason.
# - Use a conditional expression or an `if` statement to choose the label.
#
# </details>

# %% [markdown]
# ## Run the inspector on every proposal

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="https://stevens.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=c0c76340-fb78-49ec-9439-b49c00ea4935"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a></td></tr></table>

# %%
# TASK: Use a for-loop to inspect every proposal and collect the results.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Check that one result is produced per event and that the original event name is retained.

results = []
for event in event_proposals:
    result = inspect_event(event)
    results.append({"event_name": event["event_name"], **result})
    print(event["event_name"], "→", result)

# %% [markdown]
# ## Test lab
#
# Before running, predict the score for:
#
# - An empty record
# - A Saturday-only record
# - A free Friday event at 5 p.m. with seven promotion days

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="https://stevens.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=bb0e2285-3bf1-4b3d-a867-b49c00ea9784"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a></td></tr></table>

# %%
# TASK: Test normal, empty, and wrong-type inputs instead of assuming the function always receives perfect data.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Read each assertion as a claim the function must satisfy; a failed assertion identifies a broken expectation.

normal = inspect_event(event_proposals[0])
empty = inspect_event({})
boundary = inspect_event({"day_of_week": "Saturday"})
strong = inspect_event({"day_of_week": "Friday", "start_hour": 17, "free_event": True, "promotion_days": 7})

assert normal["score"] == 5
assert empty == {"label": "needs review", "score": 0, "reasons": []}
assert boundary == {"label": "possible", "score": 2, "reasons": ["weekend timing"]}
assert strong["label"] == "promising"
print("All required tests passed.")

# %% [markdown]
# ## Compare two kinds of repetition
#
# The project uses a `for` loop because it processes every known event. Trace this equivalent `while` loop, then explain which version is clearer and name one risk of forgetting to update `index`.

# %% [markdown]
# <details>
# <summary><strong>Reveal model answer</strong></summary>
#
# Use this to check your reasoning after you have written your own response.
#
# **Reference answer:** The `for` loop is clearer
# because the project needs to visit each known proposal once. The `while` loop requires a
# separate index and stopping condition. Forgetting `index += 1` would create an infinite loop.
#
# </details>

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="https://stevens.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=51848f0d-0bf9-4705-a746-b49c00eb1209"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a></td></tr></table>

# %%
# TASK: Repeat the proposal inspection with a while-loop to practice explicit loop control.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Ensure the index changes on every pass so the loop terminates after the final proposal.

index = 0
while index < len(event_proposals):
    event = event_proposals[index]
    print(index, event["event_name"])
    index += 1

# %% [markdown]
# ## Debugging evidence
#
# Read each error from the bottom line first. These controlled examples let the notebook continue. Then add one temporary print statement inside your own function, use it to inspect `score`, and remove it after the tests pass.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="https://stevens.hosted.panopto.com/Panopto/Pages/Viewer.aspx?id=de1427a6-fa3f-4acd-ab89-b49c00eb7f04"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a></td></tr></table>

# %%
# TASK: Catalog common Python errors as debugging evidence rather than executing deliberately broken code.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Use the error type, likely cause, and proposed repair to explain how you would diagnose each example.

error_examples = [
    ("NameError", "print(event_nam)"),
    ("TypeError", "print('score: ' + 4)"),
    ("IndexError", "print(event_proposals[99])"),
    ("IndentationError", "for event in event_proposals:\nprint(event)"),
]
for expected, snippet in error_examples:
    try:
        exec(snippet)
    except Exception as error:
        print(expected, "evidence →", type(error).__name__, "-", str(error).splitlines()[-1])

# Record one error: final traceback line, likely cause, repair, and proof.

# %% [markdown]
# ## Gemini coaching checkpoint
#
# Ask Gemini:
#
# > Explain my `inspect_event` function one condition at a time. Trace the Friday Game Night. Identify one edge case. Do not rewrite the function.
#
# Record:
#
# - Gemini's most important claim:
# - The code or output used to check it:
# - What was accurate:
# - What you corrected or qualified:

# %% [markdown]
# ## Explain and hand off
#
# - Why is this a human-written rule rather than machine learning?
# - Name one assumption built into the scoring system.
# - Name one event the rule might judge poorly.
#
# Save this notebook. Module 6 will replace three proposals with historical synthetic event records and ask whether the data can be trusted.

# %% [markdown]
# <details>
# <summary><strong>Reveal model answer</strong></summary>
#
# Use this to check your reasoning after you have written your own response.
#
# **Reference answer:** This is a human-written rule because
# every point and threshold was specified directly in Python; the program never learned from
# examples. One assumption is that weekend timing always deserves two points. It could judge
# an excellent Monday event poorly or overrate a weak weekend event because the rule ignores
# many real conditions.
#
# </details>

# %% [markdown]
# ## Reproducibility check
#
# Before submitting:
#
# 1. Choose **Runtime → Restart session and run all**.
# 2. Confirm all four required assertions pass in order.
# 3. Confirm no variable depends on a cell you ran out of order.
# 4. Record the Python environment as Google Colab and the date tested.
#
# A notebook that works only because of hidden runtime state is not finished.
