# %% [markdown]
# # Module 6 · Lesson 2 Word-Problem Lab
# ## Reading Your Data Like a Pro
#
# ![Space Supply Audit: find the suspicious records without erasing evidence.](attachment:m6_l2_space_supply_audit.jpg)
#
# > **ARCADE MISSION:** Space Supply Audit: find the suspicious records without erasing evidence.
#
# This notebook matches the lesson-page concept: **Inspect missing values, duplicates, ranges, and suspicious entries.**
#
# This is a short, self-contained challenge. It does **not** edit the cumulative
# **Will They Show Up?** project. You will transfer the lesson skill at the separate Model Build Checkpoint.
#
# Use this rhythm: **Accept mission → Predict → Run → Remix → Explain → Verify.**
#
# **Win condition:** finish with working code, one visible piece of evidence, and an explanation
# that a non-programmer could understand.

# %% [markdown]
# ## 1. Challenge briefing
#
# A spacecraft supply manifest contains a duplicate crate, missing inspection times, and one repair task that appears to take 900 minutes.
#
# ### Decision to make
#
# **Which inspection checks reveal each problem, and which finding needs human confirmation?**
#
# ### Your deliverable
#
# Choose and document a plausible upper bound, flag—not silently delete—values outside it, and count the affected rows.

# %% [markdown]
# ## 2. Predict before Python
#
# Predict which checks will reveal the two quality problems.
#
# Write a specific prediction and one reason. “I don’t know” is allowed only if you also identify
# the exact line or concept you need to inspect.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+WORKED+EXAMPLE%0A%23+Read+the+word+problem+first+and+predict+the+result+before+running+this+cell.%0A%23+Every+printed+value+is+evidence+you+can+cite+in+your+explanation.%0A%0Aimport+pandas+as+pd%0A%0Adata+%3D+pd.DataFrame%28%7B%0A++++%22name%22%3A+%5B%22A%22%2C+%22B%22%2C+%22B%22%2C+%22C%22%5D%2C%0A++++%22minutes%22%3A+%5B20%2C+None%2C+None%2C+900%5D%2C%0A%7D%29%0Aprint%28data.info%28%29%29%0Aprint%28%22missing%3A%5Cn%22%2C+data.isna%28%29.sum%28%29%29%0Aprint%28%22duplicates%3A%22%2C+data.duplicated%28%29.sum%28%29%29%0Aprint%28data.describe%28include%3D%22all%22%29%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# WORKED EXAMPLE
# Read the word problem first and predict the result before running this cell.
# Every printed value is evidence you can cite in your explanation.

import pandas as pd

data = pd.DataFrame({
    "name": ["A", "B", "B", "C"],
    "minutes": [20, None, None, 900],
})
print(data.info())
print("missing:\n", data.isna().sum())
print("duplicates:", data.duplicated().sum())
print(data.describe(include="all"))

# %% [markdown]
# ## 3. Read the evidence
#
# Before changing the code, explain:
#
# 1. What information went in?
# 2. Which lesson concept transformed or evaluated it?
# 3. What visible output came out?
# 4. How does that output help answer the challenge decision?
# 5. What assumption or limitation remains?
#
# Use exact variable names or output values as evidence.

# %% [markdown]
# ## 4. Solve the word problem
#
# Choose and document a plausible upper bound, flag—not silently delete—values outside it, and count the affected rows.
#
# Keep your changed code and output. Your explanation should answer the decision—not merely say
# that the code “worked.”

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+YOUR+WORD-PROBLEM+INVESTIGATION%0A%23+Mission%3A+Choose+and+document+a+plausible+upper+bound%2C+flag%E2%80%94not+silently+delete%E2%80%94values+outside+it%2C+and+count+the+affected+rows.%0A%23+Change+one+thing+at+a+time%2C+rerun%2C+and+keep+the+output+that+supports+your+answer.%0A%0Areasonable+%3D+data%5B%22minutes%22%5D.between%280%2C+180%29+%7C+data%5B%22minutes%22%5D.isna%28%29%0Aprint%28data.assign%28reasonable_minutes%3Dreasonable%29%29%0A%23+Practice%3A+define+a+different+documented+upper+bound+and+compare+the+flags."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# YOUR WORD-PROBLEM INVESTIGATION
# Mission: Choose and document a plausible upper bound, flag—not silently delete—values outside it, and count the affected rows.
# Change one thing at a time, rerun, and keep the output that supports your answer.

reasonable = data["minutes"].between(0, 180) | data["minutes"].isna()
print(data.assign(reasonable_minutes=reasonable))
# Practice: define a different documented upper bound and compare the flags.

# %% [markdown]
# ## Bonus round: Remix the challenge
#
# Choose **one** remix—small enough to test in under five minutes:
#
# - **Twist the input:** add one realistic normal case and predict its result.
# - **Break it safely:** add one edge case that might expose a weak assumption.
# - **Make it yours:** rename the fictional objects or values while preserving the lesson concept.
#
# Write your prediction first. Then use the code cell below to run the remix and record what changed.
# Your remix should still help answer this mission: **Choose and document a plausible upper bound, flag—not silently delete—values outside it, and count the affected rows.**

# %%
# BONUS ROUND WORKSPACE
# Copy only the smallest relevant part of the investigation here.
# 1. State your prediction in a comment.
# 2. Change one thing.
# 3. Print or assert the evidence.

# Your remix:
pass

# %% [markdown]
# ## 5. Verify your solution
#
# - Did you change only what the mission requested?
# - Can another person reproduce the output by running from the top?
# - Does your written answer cite a printed value, row, prediction, or test?
# - Did you distinguish what the evidence supports from what it cannot prove?
#
# <details>
# <summary><strong>Reveal one strong-answer approach</strong></summary>
#
# A strong answer separates missingness, duplication, and range validity and explains that a suspicious value is not automatically an error.
#
# </details>

# %% [markdown]
# ## 6. Optional AI helper—with verification
#
# If you are stuck, ask Gemini or another approved assistant:
#
# > I am solving a beginner Python word problem about **Reading Your Data Like a Pro**. Explain the next step
# > without replacing my whole solution. Name the exact line I should inspect and give me one
# > small test I can run.
#
# Then record:
#
# - the assistant’s claim;
# - the test you ran;
# - whether the output supported, corrected, or contradicted the claim.
#
# Never upload personal or confidential data. This notebook uses only tiny fictional examples.

# %% [markdown]
# ## 7. Exit ticket
#
# In 2–4 sentences:
#
# 1. Answer the campus decision.
# 2. Cite the strongest output evidence.
# 3. Name one limit or next check.
#
# **Achievement unlocked when:** your answer cites visible output and survives one remix or edge-case test.
#
# Save this lesson-practice notebook separately. Do not paste it into the cumulative project.
