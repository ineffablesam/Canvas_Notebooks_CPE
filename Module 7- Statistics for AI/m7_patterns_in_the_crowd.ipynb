# %% [markdown]
# # Module 7: Patterns in the Crowd
#
# **Case File 03: Will They Show Up?**
#
# You cleaned the evidence in Module 6. Now investigate the patterns before Module 8 attempts prediction. Work from top to bottom. Keep every earlier cell because later cells build on it.

# %% [markdown]
# ## Before you begin
# 1. Upload `campus_events_clean.csv` to the Colab Files panel.
# 2. Run each cell with the play button.
# 3. Read every printed result and chart label.
# 4. Use Gemini when prompted, but verify its claim against the table or chart.
# 5. Never upload real student or school data.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Import+the+tools+used+throughout+this+notebook.%0Aimport+pandas+as+pd%0Aimport+matplotlib.pyplot+as+plt%0Aimport+seaborn+as+sns%0A%0A%23+Load+the+cleaned+file+produced+by+the+Module+6+workflow.%0Adf+%3D+pd.read_csv%28%27campus_events_clean.csv%27%29%0A%23+Make+a+numeric+analysis+copy+of+the+yes%2Fno+target.+It+is+not+an+input+feature.%0Adf%5B%27high_turnout_flag%27%5D+%3D+df%5B%27high_turnout%27%5D.map%28%7B%27no%27%3A+0%2C+%27yes%27%3A+1%7D%29%0Aprint%28%27Rows+and+columns%3A%27%2C+df.shape%29%0Adf.head%28%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Import the tools used throughout this notebook.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned file produced by the Module 6 workflow.
df = pd.read_csv('campus_events_clean.csv')
# Make a numeric analysis copy of the yes/no target. It is not an input feature.
df['high_turnout_flag'] = df['high_turnout'].map({'no': 0, 'yes': 1})
print('Rows and columns:', df.shape)
df.head()

# %% [markdown]
# ## Level 1: Describe a typical event
# A mean uses every value. A median is the middle after sorting. Range is maximum minus minimum. The interquartile range, or IQR, describes the middle half of the values and is less sensitive to extremes.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Start+with+the+target-related+rate+for+description+only.%0A%23+IMPORTANT%3A+attendance_rate+and+actual_attendance+will+NOT+become+model+features.%0Acolumn+%3D+%27attendance_rate%27%0Amean_value+%3D+df%5Bcolumn%5D.mean%28%29%0Amedian_value+%3D+df%5Bcolumn%5D.median%28%29%0Arange_value+%3D+df%5Bcolumn%5D.max%28%29+-+df%5Bcolumn%5D.min%28%29%0Astandard_deviation+%3D+df%5Bcolumn%5D.std%28%29++%23+pandas+uses+the+sample+SD+by+default%0Aq1+%3D+df%5Bcolumn%5D.quantile%280.25%29%0Aq3+%3D+df%5Bcolumn%5D.quantile%280.75%29%0Aiqr+%3D+q3+-+q1%0Aprint%28f%27Mean%3A+%7Bmean_value%3A.3f%7D%27%29%0Aprint%28f%27Median%3A+%7Bmedian_value%3A.3f%7D%27%29%0Aprint%28f%27Range%3A+%7Brange_value%3A.3f%7D%27%29%0Aprint%28f%27Sample+standard+deviation%3A+%7Bstandard_deviation%3A.3f%7D%27%29%0Aprint%28f%27IQR%3A+%7Biqr%3A.3f%7D%27%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Start with the target-related rate for description only.
# IMPORTANT: attendance_rate and actual_attendance will NOT become model features.
column = 'attendance_rate'
mean_value = df[column].mean()
median_value = df[column].median()
range_value = df[column].max() - df[column].min()
standard_deviation = df[column].std()  # pandas uses the sample SD by default
q1 = df[column].quantile(0.25)
q3 = df[column].quantile(0.75)
iqr = q3 - q1
print(f'Mean: {mean_value:.3f}')
print(f'Median: {median_value:.3f}')
print(f'Range: {range_value:.3f}')
print(f'Sample standard deviation: {standard_deviation:.3f}')
print(f'IQR: {iqr:.3f}')

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+A+histogram+shows+the+distribution%2C+not+just+one+summary+number.%0Aplt.figure%28figsize%3D%288%2C+4%29%29%0Asns.histplot%28df%5B%27attendance_rate%27%5D%2C+bins%3D12%2C+color%3D%27%23A32638%27%29%0Aplt.axvline%28df%5B%27attendance_rate%27%5D.median%28%29%2C+color%3D%27black%27%2C+linestyle%3D%27--%27%2C+label%3D%27median%27%29%0Aplt.xlabel%28%27Attendance+rate%27%29%0Aplt.ylabel%28%27Number+of+events%27%29%0Aplt.title%28%27How+attendance+rates+are+distributed%27%29%0Aplt.legend%28%29%0Aplt.savefig%28%27m7_attendance_distribution.png%27%2C+dpi%3D150%2C+bbox_inches%3D%27tight%27%29%0Aplt.show%28%29%0Aprint%28%27Saved+m7_attendance_distribution.png%27%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# A histogram shows the distribution, not just one summary number.
plt.figure(figsize=(8, 4))
sns.histplot(df['attendance_rate'], bins=12, color='#A32638')
plt.axvline(df['attendance_rate'].median(), color='black', linestyle='--', label='median')
plt.xlabel('Attendance rate')
plt.ylabel('Number of events')
plt.title('How attendance rates are distributed')
plt.legend()
plt.savefig('m7_attendance_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved m7_attendance_distribution.png')

# %% [markdown]
# **Evidence note 1:** In a new markdown cell, write: The typical attendance rate was ____. I chose mean or median because ____. The range, sample standard deviation, or IQR shows ____. The distribution also shows ____.

# %% [markdown]
# ## Level 2: Investigate outliers
# The 1.5 × IQR rule flags values for investigation. A flag is not an instruction to delete. An unusual event may be an error, or it may be important evidence.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Flag+possible+outliers+in+a+pre-event+clue+with+the+IQR+rule.%0Aoutlier_column+%3D+%27previous_similar_attendance%27%0Aoutlier_q1+%3D+df%5Boutlier_column%5D.quantile%280.25%29%0Aoutlier_q3+%3D+df%5Boutlier_column%5D.quantile%280.75%29%0Aoutlier_iqr+%3D+outlier_q3+-+outlier_q1%0Alower+%3D+outlier_q1+-+1.5+%2A+outlier_iqr%0Aupper+%3D+outlier_q3+%2B+1.5+%2A+outlier_iqr%0Aflagged+%3D+df%5B%28df%5Boutlier_column%5D+%3C+lower%29+%7C+%28df%5Boutlier_column%5D+%3E+upper%29%5D%0Aprint%28%27Lower+fence%3A%27%2C+round%28lower%2C+1%29%2C+%27Upper+fence%3A%27%2C+round%28upper%2C+1%29%29%0Aprint%28%27Flagged+rows%3A%27%2C+len%28flagged%29%29%0Aflagged%5B%5B%27event_id%27%2C+%27event_type%27%2C+%27previous_similar_attendance%27%2C+%27capacity%27%5D%5D.head%2810%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Flag possible outliers in a pre-event clue with the IQR rule.
outlier_column = 'previous_similar_attendance'
outlier_q1 = df[outlier_column].quantile(0.25)
outlier_q3 = df[outlier_column].quantile(0.75)
outlier_iqr = outlier_q3 - outlier_q1
lower = outlier_q1 - 1.5 * outlier_iqr
upper = outlier_q3 + 1.5 * outlier_iqr
flagged = df[(df[outlier_column] < lower) | (df[outlier_column] > upper)]
print('Lower fence:', round(lower, 1), 'Upper fence:', round(upper, 1))
print('Flagged rows:', len(flagged))
flagged[['event_id', 'event_type', 'previous_similar_attendance', 'capacity']].head(10)

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Compare+a+box+plot+with+the+flagged+table+above.%0Aplt.figure%28figsize%3D%288%2C+2.8%29%29%0Asns.boxplot%28x%3Ddf%5B%27previous_similar_attendance%27%5D%2C+color%3D%27%23E8A33D%27%29%0Aplt.xlabel%28%27Previous+similar-event+attendance%27%29%0Aplt.title%28%27Potential+outliers+deserve+investigation%27%29%0Aplt.show%28%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Compare a box plot with the flagged table above.
plt.figure(figsize=(8, 2.8))
sns.boxplot(x=df['previous_similar_attendance'], color='#E8A33D')
plt.xlabel('Previous similar-event attendance')
plt.title('Potential outliers deserve investigation')
plt.show()

# %% [markdown]
# **Evidence note 2:** Choose one flagged event. State whether it looks impossible, unusual but plausible, or unclear. Name the evidence you would need before changing or removing it.

# %% [markdown]
# ## Level 3: Compare groups without hiding group size
# A group rate can be useful, but a dramatic result from three events is not as stable as a result from eighty events. Always show the count beside the statistic.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Compare+turnout+by+event+type+and+keep+the+group+size+visible.%0Agroup_report+%3D+%28df.groupby%28%27event_type%27%29%0A++++++++++++++++++.agg%28events%3D%28%27event_id%27%2C+%27count%27%29%2C%0A+++++++++++++++++++++++median_attendance_rate%3D%28%27attendance_rate%27%2C+%27median%27%29%2C%0A+++++++++++++++++++++++high_turnout_rate%3D%28%27high_turnout_flag%27%2C+%27mean%27%29%29%0A++++++++++++++++++.sort_values%28%27high_turnout_rate%27%2C+ascending%3DFalse%29%29%0Agroup_report.round%283%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Compare turnout by event type and keep the group size visible.
group_report = (df.groupby('event_type')
                  .agg(events=('event_id', 'count'),
                       median_attendance_rate=('attendance_rate', 'median'),
                       high_turnout_rate=('high_turnout_flag', 'mean'))
                  .sort_values('high_turnout_rate', ascending=False))
group_report.round(3)

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Plot+the+high-turnout+rate.+Read+the+table+too+because+the+chart+does+not+show+every+detail.%0Aplot_data+%3D+group_report.reset_index%28%29%0Aplt.figure%28figsize%3D%289%2C+5%29%29%0Asns.barplot%28data%3Dplot_data%2C+x%3D%27high_turnout_rate%27%2C+y%3D%27event_type%27%2C+color%3D%27%233A6EA5%27%29%0Aplt.xlim%280%2C+1%29%0Aplt.xlabel%28%27Proportion+of+events+with+high+turnout%27%29%0Aplt.ylabel%28%27Event+type%27%29%0Aplt.title%28%27High+turnout+by+event+type%27%29%0Aplt.savefig%28%27m7_turnout_by_event_type.png%27%2C+dpi%3D150%2C+bbox_inches%3D%27tight%27%29%0Aplt.show%28%29%0Aprint%28%27Saved+m7_turnout_by_event_type.png%27%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Plot the high-turnout rate. Read the table too because the chart does not show every detail.
plot_data = group_report.reset_index()
plt.figure(figsize=(9, 5))
sns.barplot(data=plot_data, x='high_turnout_rate', y='event_type', color='#3A6EA5')
plt.xlim(0, 1)
plt.xlabel('Proportion of events with high turnout')
plt.ylabel('Event type')
plt.title('High turnout by event type')
plt.savefig('m7_turnout_by_event_type.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved m7_turnout_by_event_type.png')

# %% [markdown]
# **Evidence note 3:** Write one comparison using the words *associated with* or *in this dataset*. Include both a rate and the number of events. Do not use *caused*.

# %% [markdown]
# ## Level 4: Relationships are clues, not proof
# Correlation describes the direction and strength of a linear relationship between numeric variables. It does not establish cause, and a value near zero does not rule out every kind of relationship.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Use+only+variables+known+before+the+event+for+this+relationship+check.%0Apre_event_numeric+%3D+%5B%27capacity%27%2C+%27ticket_price_usd%27%2C+%27promotion_days%27%2C%0A+++++++++++++++++++++%27social_posts%27%2C+%27poster_count%27%2C%0A+++++++++++++++++++++%27previous_similar_attendance%27%2C+%27competing_events%27%5D%0Acorr+%3D+df%5Bpre_event_numeric+%2B+%5B%27high_turnout_flag%27%5D%5D.corr%28numeric_only%3DTrue%29%5B%27high_turnout_flag%27%5D.drop%28%27high_turnout_flag%27%29%0Acorr.sort_values%28key%3Dabs%2C+ascending%3DFalse%29.round%283%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Use only variables known before the event for this relationship check.
pre_event_numeric = ['capacity', 'ticket_price_usd', 'promotion_days',
                     'social_posts', 'poster_count',
                     'previous_similar_attendance', 'competing_events']
corr = df[pre_event_numeric + ['high_turnout_flag']].corr(numeric_only=True)['high_turnout_flag'].drop('high_turnout_flag')
corr.sort_values(key=abs, ascending=False).round(3)

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Inspect+one+relationship+visually.+Each+dot+is+one+event.%0Aplt.figure%28figsize%3D%288%2C+5%29%29%0Asns.scatterplot%28data%3Ddf%2C+x%3D%27previous_similar_attendance%27%2C+y%3D%27attendance_rate%27%2C%0A++++++++++++++++hue%3D%27high_turnout%27%2C+palette%3D%7B%27no%27%3A%27%236B7280%27%2C+%27yes%27%3A%27%23A32638%27%7D%2C+alpha%3D.75%29%0Aplt.xlabel%28%27Previous+similar-event+attendance%27%29%0Aplt.ylabel%28%27Attendance+rate%27%29%0Aplt.title%28%27Previous+attendance+and+current+attendance+rate%27%29%0Aplt.savefig%28%27m7_previous_attendance_scatter.png%27%2C+dpi%3D150%2C+bbox_inches%3D%27tight%27%29%0Aplt.show%28%29%0Aprint%28%27Saved+m7_previous_attendance_scatter.png%27%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Inspect one relationship visually. Each dot is one event.
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='previous_similar_attendance', y='attendance_rate',
                hue='high_turnout', palette={'no':'#6B7280', 'yes':'#A32638'}, alpha=.75)
plt.xlabel('Previous similar-event attendance')
plt.ylabel('Attendance rate')
plt.title('Previous attendance and current attendance rate')
plt.savefig('m7_previous_attendance_scatter.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved m7_previous_attendance_scatter.png')

# %% [markdown]
# **Gemini checkpoint:** Ask: `Describe the visible relationship in this scatter plot without claiming causation. Give one possible lurking variable and one check I should perform.` Then verify every statement against the axes, the dots, and the data dictionary. Record one part you accepted and one part you corrected or qualified.

# %% [markdown]
# ## Level 5: Build the M8 feature shortlist
# A candidate feature must pass three gates: it is available before the event, it is not an identifier or target-derived answer, and there is a reasonable project justification for considering it. Statistical association alone does not guarantee usefulness or fairness.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Columns+that+must+not+be+handed+to+the+model+as+features.%0Ablocked+%3D+%7B%0A++++%27event_id%27%3A+%27identifier%2C+not+a+generalizable+clue%27%2C%0A++++%27event_date%27%3A+%27raw+date+needs+a+justified+transformation%27%2C%0A++++%27actual_weather%27%3A+%27not+known+at+advance+prediction+time%27%2C%0A++++%27actual_attendance%27%3A+%27post-event+outcome+and+direct+leakage%27%2C%0A++++%27attendance_rate%27%3A+%27directly+determines+the+target%27%2C%0A++++%27high_turnout%27%3A+%27this+is+the+target+answer%27%2C%0A++++%27high_turnout_flag%27%3A+%27analysis-only+numeric+copy+of+the+target+answer%27%0A%7D%0Apd.DataFrame%28blocked.items%28%29%2C+columns%3D%5B%27column%27%2C+%27reason%27%5D%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Columns that must not be handed to the model as features.
blocked = {
    'event_id': 'identifier, not a generalizable clue',
    'event_date': 'raw date needs a justified transformation',
    'actual_weather': 'not known at advance prediction time',
    'actual_attendance': 'post-event outcome and direct leakage',
    'attendance_rate': 'directly determines the target',
    'high_turnout': 'this is the target answer',
    'high_turnout_flag': 'analysis-only numeric copy of the target answer'
}
pd.DataFrame(blocked.items(), columns=['column', 'reason'])

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Start+a+candidate+table.+Edit+keep_for_m8+and+justification+after+reviewing+your+evidence.%0Acandidates+%3D+%5B%27capacity%27%2C+%27event_type%27%2C+%27start_hour%27%2C+%27day_of_week%27%2C%0A++++++++++++++%27weather_forecast%27%2C+%27promotion_days%27%2C+%27social_posts%27%2C%0A++++++++++++++%27poster_count%27%2C+%27food_available%27%2C+%27ticket_price_usd%27%2C%0A++++++++++++++%27previous_similar_attendance%27%2C+%27competing_events%27%5D%0Afeature_table+%3D+pd.DataFrame%28%7B%0A++++%27candidate_feature%27%3A+candidates%2C%0A++++%27available_before_event%27%3A+True%2C%0A++++%27keep_for_m8%27%3A+%27%27%2C%0A++++%27evidence_or_reason%27%3A+%27%27%2C%0A++++%27fairness_or_proxy_question%27%3A+%27%27%0A%7D%29%0Afeature_table%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Start a candidate table. Edit keep_for_m8 and justification after reviewing your evidence.
candidates = ['capacity', 'event_type', 'start_hour', 'day_of_week',
              'weather_forecast', 'promotion_days', 'social_posts',
              'poster_count', 'food_available', 'ticket_price_usd',
              'previous_similar_attendance', 'competing_events']
feature_table = pd.DataFrame({
    'candidate_feature': candidates,
    'available_before_event': True,
    'keep_for_m8': '',
    'evidence_or_reason': '',
    'fairness_or_proxy_question': ''
})
feature_table

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Use+this+helper+once+for+EACH+row.+The+first+line+is+an+example%2C+not+a+required+answer.%0Adef+record_decision%28feature%2C+keep%2C+evidence%2C+fairness_question%29%3A%0A++++mask+%3D+feature_table%5B%27candidate_feature%27%5D.eq%28feature%29%0A++++if+mask.sum%28%29+%21%3D+1%3A%0A++++++++raise+ValueError%28f%27Check+the+feature+name%3A+%7Bfeature%7D%27%29%0A++++feature_table.loc%5Bmask%2C+%5B%27keep_for_m8%27%2C+%27evidence_or_reason%27%2C+%27fairness_or_proxy_question%27%5D%5D+%3D+%5B%0A++++++++keep%2C+evidence%2C+fairness_question%0A++++%5D%0A%0Arecord_decision%28%27capacity%27%2C+%27review%27%2C%0A++++++++++++++++%27Group+summaries+suggest+capacity+deserves+testing%3B+this+does+not+prove+usefulness.%27%2C%0A++++++++++++++++%27Could+venue+size+reflect+unequal+access+to+campus+resources%3F%27%29%0A%0A%23+Copy+and+edit+record_decision%28...%29+for+every+remaining+candidate.%0Afeature_table%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Use this helper once for EACH row. The first line is an example, not a required answer.
def record_decision(feature, keep, evidence, fairness_question):
    mask = feature_table['candidate_feature'].eq(feature)
    if mask.sum() != 1:
        raise ValueError(f'Check the feature name: {feature}')
    feature_table.loc[mask, ['keep_for_m8', 'evidence_or_reason', 'fairness_or_proxy_question']] = [
        keep, evidence, fairness_question
    ]

record_decision('capacity', 'review',
                'Group summaries suggest capacity deserves testing; this does not prove usefulness.',
                'Could venue size reflect unequal access to campus resources?')

# Copy and edit record_decision(...) for every remaining candidate.
feature_table

# %% [markdown]
# ## Final deliverable: Statistical Evidence Report
# Save: (1) two labeled charts, (2) three evidence statements, (3) one limitation, (4) the completed candidate-feature table, and (5) your Gemini verification note. End with: `In Module 8, the model may test these clues, but this report does not prove that any clue causes turnout.`

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+Export+only+after+every+candidate+has+a+decision+and+explanation.%0Arequired+%3D+%5B%27keep_for_m8%27%2C+%27evidence_or_reason%27%2C+%27fairness_or_proxy_question%27%5D%0Aincomplete+%3D+feature_table%5Brequired%5D.apply%28lambda+col%3A+col.astype%28str%29.str.strip%28%29.eq%28%27%27%29%29.any%28axis%3D1%29%0Aif+incomplete.any%28%29%3A%0A++++print%28%27Not+exported+yet.+Complete+these+rows%3A%27%29%0A++++display%28feature_table.loc%5Bincomplete%2C+%5B%27candidate_feature%27%5D%5D%29%0Aelse%3A%0A++++feature_table.to_csv%28%27m7_feature_candidates_for_m8.csv%27%2C+index%3DFalse%29%0A++++print%28%27Saved+m7_feature_candidates_for_m8.csv%27%29%0A"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# Export only after every candidate has a decision and explanation.
required = ['keep_for_m8', 'evidence_or_reason', 'fairness_or_proxy_question']
incomplete = feature_table[required].apply(lambda col: col.astype(str).str.strip().eq('')).any(axis=1)
if incomplete.any():
    print('Not exported yet. Complete these rows:')
    display(feature_table.loc[incomplete, ['candidate_feature']])
else:
    feature_table.to_csv('m7_feature_candidates_for_m8.csv', index=False)
    print('Saved m7_feature_candidates_for_m8.csv')
