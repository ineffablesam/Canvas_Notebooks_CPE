# %% [markdown]
# # Module 8 · Lesson 2 Word-Problem Lab
# ## Teaching Machines to Guess Right
#
# ![Decision-Tree Doors: train a tiny classifier and inspect its choices.](attachment:m8_l2_robot_tree_doors.jpg)
#
# > **ARCADE MISSION:** Decision-Tree Doors: train a tiny classifier and inspect its choices.
#
# This notebook matches the lesson-page concept: **Fit a tiny classifier and connect predictions to measurable errors.**
#
# This is a short, self-contained challenge. It does **not** edit the cumulative
# **Will They Show Up?** project. You will transfer the lesson skill at the separate Model Build Checkpoint.
#
# Use this rhythm: **Accept mission → Predict → Run → Remix → Explain → Verify.**
#
# **Win condition:** finish with working code, one visible piece of evidence, and an explanation
# that a non-programmer could understand.

# %% [markdown]
# ## 1. Challenge briefing
#
# A robot guard uses a tiny decision tree to choose whether an incoming cargo pod may pass or needs human inspection.
#
# ### Decision to make
#
# **How does the tree learn from labeled examples, and what happens when model complexity changes?**
#
# ### Your deliverable
#
# Predict the new class, run the model, reduce max_depth to 1, and compare which training examples become mistakes.

# %% [markdown]
# ## 2. Predict before Python
#
# Predict the class for the new example before fitting.
#
# Write a specific prediction and one reason. “I don’t know” is allowed only if you also identify
# the exact line or concept you need to inspect.

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+WORKED+EXAMPLE%0A%23+Read+the+word+problem+first+and+predict+the+result+before+running+this+cell.%0A%23+Every+printed+value+is+evidence+you+can+cite+in+your+explanation.%0A%0Afrom+sklearn.tree+import+DecisionTreeClassifier%0A%0AX+%3D+%5B%5B1%2C+0%5D%2C+%5B2%2C+0%5D%2C+%5B7%2C+1%5D%2C+%5B8%2C+1%5D%2C+%5B6%2C+1%5D%2C+%5B3%2C+0%5D%5D%0Ay+%3D+%5B%22safe%22%2C+%22safe%22%2C+%22review%22%2C+%22review%22%2C+%22review%22%2C+%22safe%22%5D%0Amodel+%3D+DecisionTreeClassifier%28max_depth%3D2%2C+random_state%3D0%29%0Amodel.fit%28X%2C+y%29%0Aprint%28%22prediction%3A%22%2C+model.predict%28%5B%5B5%2C+1%5D%5D%29%5B0%5D%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# WORKED EXAMPLE
# Read the word problem first and predict the result before running this cell.
# Every printed value is evidence you can cite in your explanation.

from sklearn.tree import DecisionTreeClassifier

X = [[1, 0], [2, 0], [7, 1], [8, 1], [6, 1], [3, 0]]
y = ["safe", "safe", "review", "review", "review", "safe"]
model = DecisionTreeClassifier(max_depth=2, random_state=0)
model.fit(X, y)
print("prediction:", model.predict([[5, 1]])[0])

# %% [markdown]
# ## 3. Read the evidence
#
# Before changing the code, explain:
#
# 1. What information went in?
# 2. Which lesson concept transformed or evaluated it?
# 3. What visible output came out?
# 4. How does that output help answer the challenge decision?
# 5. What assumption or limitation remains?
#
# Use exact variable names or output values as evidence.

# %% [markdown]
# ## 4. Solve the word problem
#
# Predict the new class, run the model, reduce max_depth to 1, and compare which training examples become mistakes.
#
# Keep your changed code and output. Your explanation should answer the decision—not merely say
# that the code “worked.”

# %% [markdown]
# <table width="100%"><tr><td>&#128269;&nbsp;<b>Stuck on this code?</b></td><td align="right"><a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&logo=youtube&logoColor=white"></a> <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+YOUR+WORD-PROBLEM+INVESTIGATION%0A%23+Mission%3A+Predict+the+new+class%2C+run+the+model%2C+reduce+max_depth+to+1%2C+and+compare+which+training+examples+become+mistakes.%0A%23+Change+one+thing+at+a+time%2C+rerun%2C+and+keep+the+output+that+supports+your+answer.%0A%0Apredictions+%3D+model.predict%28X%29%0Afor+features%2C+actual%2C+predicted+in+zip%28X%2C+y%2C+predictions%29%3A%0A++++print%28features%2C+%22actual%3D%22%2C+actual%2C+%22predicted%3D%22%2C+predicted%29%0A%23+Practice%3A+change+max_depth+to+1+and+compare+the+training+mistakes."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat"></a></td></tr></table>

# %%
# YOUR WORD-PROBLEM INVESTIGATION
# Mission: Predict the new class, run the model, reduce max_depth to 1, and compare which training examples become mistakes.
# Change one thing at a time, rerun, and keep the output that supports your answer.

predictions = model.predict(X)
for features, actual, predicted in zip(X, y, predictions):
    print(features, "actual=", actual, "predicted=", predicted)
# Practice: change max_depth to 1 and compare the training mistakes.

# %% [markdown]
# ## Bonus round: Remix the challenge
#
# Choose **one** remix—small enough to test in under five minutes:
#
# - **Twist the input:** add one realistic normal case and predict its result.
# - **Break it safely:** add one edge case that might expose a weak assumption.
# - **Make it yours:** rename the fictional objects or values while preserving the lesson concept.
#
# Write your prediction first. Then use the code cell below to run the remix and record what changed.
# Your remix should still help answer this mission: **Predict the new class, run the model, reduce max_depth to 1, and compare which training examples become mistakes.**

# %%
# BONUS ROUND WORKSPACE
# Copy only the smallest relevant part of the investigation here.
# 1. State your prediction in a comment.
# 2. Change one thing.
# 3. Print or assert the evidence.

# Your remix:
pass

# %% [markdown]
# ## 5. Verify your solution
#
# - Did you change only what the mission requested?
# - Can another person reproduce the output by running from the top?
# - Does your written answer cite a printed value, row, prediction, or test?
# - Did you distinguish what the evidence supports from what it cannot prove?
#
# <details>
# <summary><strong>Reveal one strong-answer approach</strong></summary>
#
# A strong answer distinguishes fitting from predicting and uses changed errors as evidence about model capacity.
#
# </details>

# %% [markdown]
# ## 6. Optional AI helper—with verification
#
# If you are stuck, ask Gemini or another approved assistant:
#
# > I am solving a beginner Python word problem about **Teaching Machines to Guess Right**. Explain the next step
# > without replacing my whole solution. Name the exact line I should inspect and give me one
# > small test I can run.
#
# Then record:
#
# - the assistant’s claim;
# - the test you ran;
# - whether the output supported, corrected, or contradicted the claim.
#
# Never upload personal or confidential data. This notebook uses only tiny fictional examples.

# %% [markdown]
# ## 7. Exit ticket
#
# In 2–4 sentences:
#
# 1. Answer the campus decision.
# 2. Cite the strongest output evidence.
# 3. Name one limit or next check.
#
# **Achievement unlocked when:** your answer cites visible output and survives one remix or edge-case test.
#
# Save this lesson-practice notebook separately. Do not paste it into the cumulative project.
