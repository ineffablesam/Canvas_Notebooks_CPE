# %% [markdown]
# # Will They Show Up? · Module 8
#
# This continues **Will They Show Up?** Parts 1–3 are compact reference code. Part 4 is your current work.
#
# ## Part 4 mission
#
# **Question:** What exactly should the model learn, and how will we judge it?
#
# **Build:** Lock the target, approved features, leakage exclusions, split strategy, baseline, candidate algorithms, and metrics.
#
# **Save:** A machine-readable model blueprint created before final evaluation.

# %%
# This checkpoint visual is embedded in the notebook output.
# It does not depend on a local image path and should display in Colab.
# Out:
# <Embedded Module 8 checkpoint visual>

# %% [markdown]
# ## Start
#
# - `campus_events_development_raw.csv`
# - `campus_events_data_dictionary.csv`
#
# The final holdout is intentionally **not** provided yet.
#
# 1. Open in Colab and choose **File → Save a copy in Drive**.
# 2. Run cells from top to bottom.
# Upload the CSV files before running the first data cell.
#
# All records are synthetic. If Colab resets, upload the CSV files again.

# %% [markdown]
# ---
#
# # Part 1 · Released reference solution from an earlier checkpoint
#
# Run this section in order. Earlier reference code creates the handoffs needed below.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Create+three+fictional+event+proposals+using+dictionaries+inside+a+list.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Confirm+that+every+proposal+has+the+same+five+fields%3B+later+cells+depend+on+those+exact+names.%0A%0Aevent_proposals+%3D+%5B%0A++++%7B%22event_name%22%3A+%22Friday+Game+Night%22%2C+%22day_of_week%22%3A+%22Friday%22%2C+%22start_hour%22%3A+18%2C+%22free_event%22%3A+True%2C+%22promotion_days%22%3A+10%7D%2C%0A++++%7B%22event_name%22%3A+%22Monday+Sunrise+Talk%22%2C+%22day_of_week%22%3A+%22Monday%22%2C+%22start_hour%22%3A+7%2C+%22free_event%22%3A+False%2C+%22promotion_days%22%3A+1%7D%2C%0A++++%7B%22event_name%22%3A+%22Saturday+Film+Night%22%2C+%22day_of_week%22%3A+%22Saturday%22%2C+%22start_hour%22%3A+19%2C+%22free_event%22%3A+True%2C+%22promotion_days%22%3A+4%7D%2C%0A%5D%0A%0Afor+event+in+event_proposals%3A%0A++++print%28event%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Create three fictional event proposals using dictionaries inside a list.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Confirm that every proposal has the same five fields; later cells depend on those exact names.

event_proposals = [
    {"event_name": "Friday Game Night", "day_of_week": "Friday", "start_hour": 18, "free_event": True, "promotion_days": 10},
    {"event_name": "Monday Sunrise Talk", "day_of_week": "Monday", "start_hour": 7, "free_event": False, "promotion_days": 1},
    {"event_name": "Saturday Film Night", "day_of_week": "Saturday", "start_hour": 19, "free_event": True, "promotion_days": 4},
]

for event in event_proposals:
    print(event)

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Demonstrate+a+tuple+for+fixed+field+order%2C+a+set+for+unique+weekdays%2C+and+a+dictionary+lookup.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Compare+what+each+collection+preserves%3A+order%2C+uniqueness%2C+or+key-to-value+meaning.%0A%0Afixed_field_order+%3D+%28%22event_name%22%2C+%22day_of_week%22%2C+%22start_hour%22%2C+%22free_event%22%2C+%22promotion_days%22%29%0Aunique_days+%3D+%7Bevent%5B%22day_of_week%22%5D+for+event+in+event_proposals%7D%0Afirst_event+%3D+event_proposals%5B0%5D%0A%0Aprint%28%22List+length%3A%22%2C+len%28event_proposals%29%2C+type%28event_proposals%29.__name__%29%0Aprint%28%22Fixed+tuple%3A%22%2C+fixed_field_order%2C+type%28fixed_field_order%29.__name__%29%0Aprint%28%22Unique-day+set%3A%22%2C+unique_days%2C+type%28unique_days%29.__name__%29%0Aprint%28%22One+dictionary%3A%22%2C+first_event%2C+type%28first_event%29.__name__%29%0A%0A%23+Explain+why+each+collection+fits+its+job.+Then+add+one+safe+field+to+first_event."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Demonstrate a tuple for fixed field order, a set for unique weekdays, and a dictionary lookup.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Compare what each collection preserves: order, uniqueness, or key-to-value meaning.

fixed_field_order = ("event_name", "day_of_week", "start_hour", "free_event", "promotion_days")
unique_days = {event["day_of_week"] for event in event_proposals}
first_event = event_proposals[0]

print("List length:", len(event_proposals), type(event_proposals).__name__)
print("Fixed tuple:", fixed_field_order, type(fixed_field_order).__name__)
print("Unique-day set:", unique_days, type(unique_days).__name__)
print("One dictionary:", first_event, type(first_event).__name__)

# Explain why each collection fits its job. Then add one safe field to first_event.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Define+the+transparent+rule-based+Event+Inspector+used+before+machine+learning.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Trace+each+condition+and+verify+that+the+returned+score%2C+label%2C+and+reasons+agree+with+one+another.%0A%0Adef+inspect_event%28event%29%3A%0A++++score+%3D+0%0A++++reasons+%3D+%5B%5D%0A%0A++++if+event.get%28%22day_of_week%22%29+in+%5B%22Friday%22%2C+%22Saturday%22%5D%3A%0A++++++++score+%2B%3D+2%0A++++++++reasons.append%28%22weekend+timing%22%29%0A++++if+event.get%28%22start_hour%22%29+in+%5B17%2C+18%2C+19%5D%3A%0A++++++++score+%2B%3D+1%0A++++++++reasons.append%28%22after-school+start%22%29%0A++++if+event.get%28%22free_event%22%29+is+True%3A%0A++++++++score+%2B%3D+1%0A++++++++reasons.append%28%22free+admission%22%29%0A++++if+event.get%28%22promotion_days%22%2C+0%29+%3E%3D+7%3A%0A++++++++score+%2B%3D+1%0A++++++++reasons.append%28%22at+least+one+week+of+promotion%22%29%0A%0A++++if+score+%3E%3D+4%3A%0A++++++++label+%3D+%22promising%22%0A++++elif+score+%3E%3D+2%3A%0A++++++++label+%3D+%22possible%22%0A++++else%3A%0A++++++++label+%3D+%22needs+review%22%0A++++return+%7B%22label%22%3A+label%2C+%22score%22%3A+score%2C+%22reasons%22%3A+reasons%7D"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Define the transparent rule-based Event Inspector used before machine learning.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Trace each condition and verify that the returned score, label, and reasons agree with one another.

def inspect_event(event):
    score = 0
    reasons = []

    if event.get("day_of_week") in ["Friday", "Saturday"]:
        score += 2
        reasons.append("weekend timing")
    if event.get("start_hour") in [17, 18, 19]:
        score += 1
        reasons.append("after-school start")
    if event.get("free_event") is True:
        score += 1
        reasons.append("free admission")
    if event.get("promotion_days", 0) >= 7:
        score += 1
        reasons.append("at least one week of promotion")

    if score >= 4:
        label = "promising"
    elif score >= 2:
        label = "possible"
    else:
        label = "needs review"
    return {"label": label, "score": score, "reasons": reasons}

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Use+a+for-loop+to+inspect+every+proposal+and+collect+the+results.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Check+that+one+result+is+produced+per+event+and+that+the+original+event+name+is+retained.%0A%0Aresults+%3D+%5B%5D%0Afor+event+in+event_proposals%3A%0A++++result+%3D+inspect_event%28event%29%0A++++results.append%28%7B%22event_name%22%3A+event%5B%22event_name%22%5D%2C+%2A%2Aresult%7D%29%0A++++print%28event%5B%22event_name%22%5D%2C+%22%E2%86%92%22%2C+result%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Use a for-loop to inspect every proposal and collect the results.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Check that one result is produced per event and that the original event name is retained.

results = []
for event in event_proposals:
    result = inspect_event(event)
    results.append({"event_name": event["event_name"], **result})
    print(event["event_name"], "→", result)

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Test+normal%2C+empty%2C+and+wrong-type+inputs+instead+of+assuming+the+function+always+receives+perfect+data.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Read+each+assertion+as+a+claim+the+function+must+satisfy%3B+a+failed+assertion+identifies+a+broken+expectation.%0A%0Anormal+%3D+inspect_event%28event_proposals%5B0%5D%29%0Aempty+%3D+inspect_event%28%7B%7D%29%0Aboundary+%3D+inspect_event%28%7B%22day_of_week%22%3A+%22Saturday%22%7D%29%0Astrong+%3D+inspect_event%28%7B%22day_of_week%22%3A+%22Friday%22%2C+%22start_hour%22%3A+17%2C+%22free_event%22%3A+True%2C+%22promotion_days%22%3A+7%7D%29%0A%0Aassert+normal%5B%22score%22%5D+%3D%3D+5%0Aassert+empty+%3D%3D+%7B%22label%22%3A+%22needs+review%22%2C+%22score%22%3A+0%2C+%22reasons%22%3A+%5B%5D%7D%0Aassert+boundary+%3D%3D+%7B%22label%22%3A+%22possible%22%2C+%22score%22%3A+2%2C+%22reasons%22%3A+%5B%22weekend+timing%22%5D%7D%0Aassert+strong%5B%22label%22%5D+%3D%3D+%22promising%22%0Aprint%28%22All+required+tests+passed.%22%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Test normal, empty, and wrong-type inputs instead of assuming the function always receives perfect data.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Read each assertion as a claim the function must satisfy; a failed assertion identifies a broken expectation.

normal = inspect_event(event_proposals[0])
empty = inspect_event({})
boundary = inspect_event({"day_of_week": "Saturday"})
strong = inspect_event({"day_of_week": "Friday", "start_hour": 17, "free_event": True, "promotion_days": 7})

assert normal["score"] == 5
assert empty == {"label": "needs review", "score": 0, "reasons": []}
assert boundary == {"label": "possible", "score": 2, "reasons": ["weekend timing"]}
assert strong["label"] == "promising"
print("All required tests passed.")

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Repeat+the+proposal+inspection+with+a+while-loop+to+practice+explicit+loop+control.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Ensure+the+index+changes+on+every+pass+so+the+loop+terminates+after+the+final+proposal.%0A%0Aindex+%3D+0%0Awhile+index+%3C+len%28event_proposals%29%3A%0A++++event+%3D+event_proposals%5Bindex%5D%0A++++print%28index%2C+event%5B%22event_name%22%5D%29%0A++++index+%2B%3D+1"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Repeat the proposal inspection with a while-loop to practice explicit loop control.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Ensure the index changes on every pass so the loop terminates after the final proposal.

index = 0
while index < len(event_proposals):
    event = event_proposals[index]
    print(index, event["event_name"])
    index += 1

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Catalog+common+Python+errors+as+debugging+evidence+rather+than+executing+deliberately+broken+code.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Use+the+error+type%2C+likely+cause%2C+and+proposed+repair+to+explain+how+you+would+diagnose+each+example.%0A%0Aerror_examples+%3D+%5B%0A++++%28%22NameError%22%2C+%22print%28event_nam%29%22%29%2C%0A++++%28%22TypeError%22%2C+%22print%28%27score%3A+%27+%2B+4%29%22%29%2C%0A++++%28%22IndexError%22%2C+%22print%28event_proposals%5B99%5D%29%22%29%2C%0A++++%28%22IndentationError%22%2C+%22for+event+in+event_proposals%3A%5Cnprint%28event%29%22%29%2C%0A%5D%0Afor+expected%2C+snippet+in+error_examples%3A%0A++++try%3A%0A++++++++exec%28snippet%29%0A++++except+Exception+as+error%3A%0A++++++++print%28expected%2C+%22evidence+%E2%86%92%22%2C+type%28error%29.__name__%2C+%22-%22%2C+str%28error%29.splitlines%28%29%5B-1%5D%29%0A%0A%23+Record+one+error%3A+final+traceback+line%2C+likely+cause%2C+repair%2C+and+proof."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Catalog common Python errors as debugging evidence rather than executing deliberately broken code.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Use the error type, likely cause, and proposed repair to explain how you would diagnose each example.

error_examples = [
    ("NameError", "print(event_nam)"),
    ("TypeError", "print('score: ' + 4)"),
    ("IndexError", "print(event_proposals[99])"),
    ("IndentationError", "for event in event_proposals:\nprint(event)"),
]
for expected, snippet in error_examples:
    try:
        exec(snippet)
    except Exception as error:
        print(expected, "evidence →", type(error).__name__, "-", str(error).splitlines()[-1])

# Record one error: final traceback line, likely cause, repair, and proof.

# %% [markdown]
# ---
#
# # Part 2 · Released reference solution from an earlier checkpoint
#
# Run this section in order. Earlier reference code creates the handoffs needed below.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Import+the+data+tools%2C+locate+the+two+Canvas-supplied+CSV+files%2C+and+load+them+into+DataFrames.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Do+not+continue+unless+both+filenames+appear+in+Colab+and+the+printed+shapes+are+plausible.%0A%0Aimport+pandas+as+pd%0Afrom+pathlib+import+Path%0A%0ARAW+%3D+Path%28%22campus_events_development_raw.csv%22%29%0ADICTIONARY+%3D+Path%28%22campus_events_data_dictionary.csv%22%29%0Aif+not+RAW.exists%28%29+or+not+DICTIONARY.exists%28%29%3A%0A++++raise+FileNotFoundError%28%22Upload+both+required+files%2C+then+rerun.%22%29%0A%0Araw+%3D+pd.read_csv%28RAW%29%0Adictionary+%3D+pd.read_csv%28DICTIONARY%29%0Aprint%28%22Raw+shape%3A%22%2C+raw.shape%29%0Araw.head%28%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Import the data tools, locate the two Canvas-supplied CSV files, and load them into DataFrames.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Do not continue unless both filenames appear in Colab and the printed shapes are plausible.

import pandas as pd
from pathlib import Path

RAW = Path("campus_events_development_raw.csv")
DICTIONARY = Path("campus_events_data_dictionary.csv")
if not RAW.exists() or not DICTIONARY.exists():
    raise FileNotFoundError("Upload both required files, then rerun.")

raw = pd.read_csv(RAW)
dictionary = pd.read_csv(DICTIONARY)
print("Raw shape:", raw.shape)
raw.head()

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Preview+a+few+raw+rows+before+cleaning+so+changes+remain+evidence-based.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Look+for+inconsistent+capitalization%2C+spacing%2C+formats%2C+missing+values%2C+and+impossible-looking+entries.%0A%0Aprint%28%22First+three+rows%3A%22%29%0Adisplay%28raw.head%283%29%29%0Aprint%28%22Last+three+rows%3A%22%29%0Adisplay%28raw.tail%283%29%29%0Aprint%28%22Rows+and+columns%3A%22%2C+raw.shape%29%0Aprint%28%22Column+names%3A%22%2C+raw.columns.tolist%28%29%29%0Aprint%28%22Data+types%3A%22%29%0Aprint%28raw.dtypes%29%0Aprint%28%22Missing+values+by+column%3A%22%29%0Aprint%28raw.isna%28%29.sum%28%29.sort_values%28ascending%3DFalse%29.head%2810%29%29%0Aprint%28%22Exact+duplicates%3A%22%2C+int%28raw.duplicated%28%29.sum%28%29%29%29%0Adisplay%28raw.describe%28include%3D%22all%22%29.transpose%28%29.head%2812%29%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Preview a few raw rows before cleaning so changes remain evidence-based.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Look for inconsistent capitalization, spacing, formats, missing values, and impossible-looking entries.

print("First three rows:")
display(raw.head(3))
print("Last three rows:")
display(raw.tail(3))
print("Rows and columns:", raw.shape)
print("Column names:", raw.columns.tolist())
print("Data types:")
print(raw.dtypes)
print("Missing values by column:")
print(raw.isna().sum().sort_values(ascending=False).head(10))
print("Exact duplicates:", int(raw.duplicated().sum()))
display(raw.describe(include="all").transpose().head(12))

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Measure+the+raw+table%27s+columns%2C+missing+cells%2C+duplicates%2C+data+types%2C+and+target+balance.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Record+the+baseline+condition+now+so+the+later+health+report+can+prove+what+cleaning+changed.%0A%0Aprint%28%22Columns%3A%22%2C+raw.columns.tolist%28%29%29%0Aprint%28%22Missing+cells%3A%22%2C+int%28raw.isna%28%29.sum%28%29.sum%28%29%29%29%0Aprint%28%22Exact+duplicates%3A%22%2C+int%28raw.duplicated%28%29.sum%28%29%29%29%0Aprint%28%22Repeated+event+IDs%3A%22%2C+int%28raw.duplicated%28subset%3D%5B%22event_id%22%5D%29.sum%28%29%29%29%0Aprint%28raw%5B%5B%22actual_attendance%22%2C+%22capacity%22%2C+%22attendance_rate%22%2C+%22high_turnout%22%5D%5D.describe%28include%3D%22all%22%29%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Measure the raw table's columns, missing cells, duplicates, data types, and target balance.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Record the baseline condition now so the later health report can prove what cleaning changed.

print("Columns:", raw.columns.tolist())
print("Missing cells:", int(raw.isna().sum().sum()))
print("Exact duplicates:", int(raw.duplicated().sum()))
print("Repeated event IDs:", int(raw.duplicated(subset=["event_id"]).sum()))
print(raw[["actual_attendance", "capacity", "attendance_rate", "high_turnout"]].describe(include="all"))

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Create+a+separate+clean+copy+and+apply+the+documented+normalization+and+validity+rules.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Never+silently+overwrite+the+raw+evidence%3B+connect+every+conversion%2C+replacement%2C+or+imputation+to+a+stated+rule.%0A%0Aclean+%3D+raw.copy%28%29%0Afor+column+in+%5B%22event_type%22%2C+%22organizer_type%22%2C+%22day_of_week%22%2C+%22venue_type%22%2C%0A+++++++++++++++%22indoor_outdoor%22%2C+%22registration_required%22%2C+%22free_event%22%2C%0A+++++++++++++++%22food_available%22%2C+%22food_type%22%2C+%22prize_available%22%2C%0A+++++++++++++++%22email_campaign%22%2C+%22weather_forecast%22%2C+%22actual_weather%22%2C%0A+++++++++++++++%22campus_activity_level%22%2C+%22high_turnout%22%5D%3A%0A++++clean%5Bcolumn%5D+%3D+clean%5Bcolumn%5D.astype%28%22string%22%29.str.strip%28%29.str.lower%28%29%0A%0Aclean%5B%22day_of_week%22%5D+%3D+clean%5B%22day_of_week%22%5D.replace%28%7B%22fri%22%3A+%22friday%22%7D%29%0Aclean%5B%22actual_weather%22%5D+%3D+clean%5B%22actual_weather%22%5D.replace%28%7B%22rainy%22%3A+%22rain%22%7D%29%0Afor+column+in+%5B%22registration_required%22%2C+%22free_event%22%2C+%22food_available%22%2C%0A+++++++++++++++%22prize_available%22%2C+%22email_campaign%22%2C+%22high_turnout%22%5D%3A%0A++++clean%5Bcolumn%5D+%3D+clean%5Bcolumn%5D.replace%28%7B%22y%22%3A+%22yes%22%2C+%22n%22%3A+%22no%22%2C+%22true%22%3A+%22yes%22%2C+%22false%22%3A+%22no%22%7D%29%0A%0Aclean%5B%22ticket_price_usd%22%5D+%3D+clean%5B%22ticket_price_usd%22%5D.astype%28%22string%22%29.str.replace%28%22%24%22%2C+%22%22%2C+regex%3DFalse%29%0Anumeric_columns+%3D+%5B%22start_hour%22%2C+%22duration_hours%22%2C+%22capacity%22%2C+%22accessibility_score%22%2C%0A+++++++++++++++++++%22ticket_price_usd%22%2C+%22promotion_days%22%2C+%22promotion_channels%22%2C%0A+++++++++++++++++++%22social_posts%22%2C+%22poster_count%22%2C+%22competing_events%22%2C%0A+++++++++++++++++++%22previous_similar_attendance%22%2C+%22actual_attendance%22%2C+%22attendance_rate%22%5D%0Afor+column+in+numeric_columns%3A%0A++++clean%5Bcolumn%5D+%3D+pd.to_numeric%28clean%5Bcolumn%5D%2C+errors%3D%22coerce%22%29%0A%0Aclean+%3D+clean.drop_duplicates%28%29.copy%28%29%0Aclean.loc%5B~clean%5B%22duration_hours%22%5D.between%280.5%2C+12%29%2C+%22duration_hours%22%5D+%3D+pd.NA%0Aclean.loc%5Bclean%5B%22ticket_price_usd%22%5D+%3C+0%2C+%22ticket_price_usd%22%5D+%3D+pd.NA%0Aclean.loc%5B~clean%5B%22accessibility_score%22%5D.between%281%2C+5%29%2C+%22accessibility_score%22%5D+%3D+pd.NA%0Aclean.loc%5B~clean%5B%22poster_count%22%5D.between%280%2C+200%29%2C+%22poster_count%22%5D+%3D+pd.NA%0A%0Aunresolved_outcome+%3D+clean%5B%22actual_attendance%22%5D.isna%28%29+%7C+clean%5B%22actual_attendance%22%5D.lt%280%29+%7C+clean%5B%22actual_attendance%22%5D.gt%28clean%5B%22capacity%22%5D%29%0Aclean+%3D+clean.loc%5B~unresolved_outcome%5D.copy%28%29%0Aclean%5B%22attendance_rate%22%5D+%3D+%28clean%5B%22actual_attendance%22%5D+%2F+clean%5B%22capacity%22%5D%29.round%283%29%0Aclean%5B%22high_turnout%22%5D+%3D+clean%5B%22attendance_rate%22%5D.ge%280.65%29.map%28%7BTrue%3A+%22yes%22%2C+False%3A+%22no%22%7D%29%0Aclean%5B%22target_quality%22%5D+%3D+%22observed%22%0Aprint%28%22Clean+rows%3A%22%2C+len%28clean%29%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Create a separate clean copy and apply the documented normalization and validity rules.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Never silently overwrite the raw evidence; connect every conversion, replacement, or imputation to a stated rule.

clean = raw.copy()
for column in ["event_type", "organizer_type", "day_of_week", "venue_type",
               "indoor_outdoor", "registration_required", "free_event",
               "food_available", "food_type", "prize_available",
               "email_campaign", "weather_forecast", "actual_weather",
               "campus_activity_level", "high_turnout"]:
    clean[column] = clean[column].astype("string").str.strip().str.lower()

clean["day_of_week"] = clean["day_of_week"].replace({"fri": "friday"})
clean["actual_weather"] = clean["actual_weather"].replace({"rainy": "rain"})
for column in ["registration_required", "free_event", "food_available",
               "prize_available", "email_campaign", "high_turnout"]:
    clean[column] = clean[column].replace({"y": "yes", "n": "no", "true": "yes", "false": "no"})

clean["ticket_price_usd"] = clean["ticket_price_usd"].astype("string").str.replace("$", "", regex=False)
numeric_columns = ["start_hour", "duration_hours", "capacity", "accessibility_score",
                   "ticket_price_usd", "promotion_days", "promotion_channels",
                   "social_posts", "poster_count", "competing_events",
                   "previous_similar_attendance", "actual_attendance", "attendance_rate"]
for column in numeric_columns:
    clean[column] = pd.to_numeric(clean[column], errors="coerce")

clean = clean.drop_duplicates().copy()
clean.loc[~clean["duration_hours"].between(0.5, 12), "duration_hours"] = pd.NA
clean.loc[clean["ticket_price_usd"] < 0, "ticket_price_usd"] = pd.NA
clean.loc[~clean["accessibility_score"].between(1, 5), "accessibility_score"] = pd.NA
clean.loc[~clean["poster_count"].between(0, 200), "poster_count"] = pd.NA

unresolved_outcome = clean["actual_attendance"].isna() | clean["actual_attendance"].lt(0) | clean["actual_attendance"].gt(clean["capacity"])
clean = clean.loc[~unresolved_outcome].copy()
clean["attendance_rate"] = (clean["actual_attendance"] / clean["capacity"]).round(3)
clean["high_turnout"] = clean["attendance_rate"].ge(0.65).map({True: "yes", False: "no"})
clean["target_quality"] = "observed"
print("Clean rows:", len(clean))

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Build+a+compact+before%2Fafter+health+report.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Verify+that+row+counts%2C+missingness%2C+duplicates%2C+and+unique+IDs+tell+a+coherent+cleaning+story.%0A%0Ahealth_report+%3D+pd.DataFrame%28%7B%0A++++%22measure%22%3A+%5B%22rows%22%2C+%22columns%22%2C+%22missing+cells%22%2C+%22exact+duplicates%22%2C+%22unique+event+IDs%22%5D%2C%0A++++%22raw%22%3A+%5Blen%28raw%29%2C+raw.shape%5B1%5D%2C+int%28raw.isna%28%29.sum%28%29.sum%28%29%29%2C+int%28raw.duplicated%28%29.sum%28%29%29%2C+raw%5B%22event_id%22%5D.nunique%28%29%5D%2C%0A++++%22clean%22%3A+%5Blen%28clean%29%2C+clean.shape%5B1%5D%2C+int%28clean.isna%28%29.sum%28%29.sum%28%29%29%2C+int%28clean.duplicated%28%29.sum%28%29%29%2C+clean%5B%22event_id%22%5D.nunique%28%29%5D%2C%0A%7D%29%0Adisplay%28health_report%29%0A%0Acleaning_log+%3D+pd.DataFrame%28%5B%0A++++%7B%22issue%22%3A+%22inconsistent+category+text%22%2C+%22action%22%3A+%22standardized+documented+forms%22%2C+%22evidence_or_limit%22%3A+%22unknown+meanings+were+not+guessed%22%7D%2C%0A++++%7B%22issue%22%3A+%22numeric+text+and+invalid+ranges%22%2C+%22action%22%3A+%22coerced+and+checked+against+documented+bounds%22%2C+%22evidence_or_limit%22%3A+%22source+confirmation+may+still+be+needed%22%7D%2C%0A++++%7B%22issue%22%3A+%22exact+duplicates%22%2C+%22action%22%3A+%22removed+exact+repeated+records%22%2C+%22evidence_or_limit%22%3A+%22similar+events+were+not+treated+as+duplicates%22%7D%2C%0A++++%7B%22issue%22%3A+%22unresolved+attendance+outcome%22%2C+%22action%22%3A+%22excluded+from+supervised-learning+data%22%2C+%22evidence_or_limit%22%3A+%22the+target+was+not+imputed%22%7D%2C%0A%5D%29%0Adisplay%28cleaning_log%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Build a compact before/after health report.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Verify that row counts, missingness, duplicates, and unique IDs tell a coherent cleaning story.

health_report = pd.DataFrame({
    "measure": ["rows", "columns", "missing cells", "exact duplicates", "unique event IDs"],
    "raw": [len(raw), raw.shape[1], int(raw.isna().sum().sum()), int(raw.duplicated().sum()), raw["event_id"].nunique()],
    "clean": [len(clean), clean.shape[1], int(clean.isna().sum().sum()), int(clean.duplicated().sum()), clean["event_id"].nunique()],
})
display(health_report)

cleaning_log = pd.DataFrame([
    {"issue": "inconsistent category text", "action": "standardized documented forms", "evidence_or_limit": "unknown meanings were not guessed"},
    {"issue": "numeric text and invalid ranges", "action": "coerced and checked against documented bounds", "evidence_or_limit": "source confirmation may still be needed"},
    {"issue": "exact duplicates", "action": "removed exact repeated records", "evidence_or_limit": "similar events were not treated as duplicates"},
    {"issue": "unresolved attendance outcome", "action": "excluded from supervised-learning data", "evidence_or_limit": "the target was not imputed"},
])
display(cleaning_log)

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Practice+filtering%2C+sorting%2C+and+grouped+summaries+on+the+cleaned+records.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Interpret+what+each+result+means+for+campus-event+planning+instead+of+treating+it+as+mere+table+manipulation.%0A%0Arainy_outdoor+%3D+%28clean%5B%0A++++clean%5B%22indoor_outdoor%22%5D.eq%28%22outdoor%22%29+%26+clean%5B%22actual_weather%22%5D.eq%28%22rain%22%29%0A%5D%5B%5B%22event_id%22%2C+%22event_type%22%2C+%22capacity%22%2C+%22actual_attendance%22%2C+%22attendance_rate%22%5D%5D%0A+.sort_values%28%22attendance_rate%22%29%29%0Adisplay%28rainy_outdoor.head%2810%29%29%0A%0Agroup_summary+%3D+%28clean.groupby%28%22food_available%22%29%0A+++++++++++++++++.agg%28events%3D%28%22event_id%22%2C+%22size%22%29%2C%0A++++++++++++++++++++++mean_attendance_rate%3D%28%22attendance_rate%22%2C+%22mean%22%29%2C%0A++++++++++++++++++++++median_attendance_rate%3D%28%22attendance_rate%22%2C+%22median%22%29%2C%0A++++++++++++++++++++++minimum_rate%3D%28%22attendance_rate%22%2C+%22min%22%29%2C%0A++++++++++++++++++++++maximum_rate%3D%28%22attendance_rate%22%2C+%22max%22%29%29%0A+++++++++++++++++.round%283%29%29%0Adisplay%28group_summary%29%0A%0A%23+Write+one+descriptive+sentence+and+one+causal+claim+the+table+does+NOT+support."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Practice filtering, sorting, and grouped summaries on the cleaned records.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Interpret what each result means for campus-event planning instead of treating it as mere table manipulation.

rainy_outdoor = (clean[
    clean["indoor_outdoor"].eq("outdoor") & clean["actual_weather"].eq("rain")
][["event_id", "event_type", "capacity", "actual_attendance", "attendance_rate"]]
 .sort_values("attendance_rate"))
display(rainy_outdoor.head(10))

group_summary = (clean.groupby("food_available")
                 .agg(events=("event_id", "size"),
                      mean_attendance_rate=("attendance_rate", "mean"),
                      median_attendance_rate=("attendance_rate", "median"),
                      minimum_rate=("attendance_rate", "min"),
                      maximum_rate=("attendance_rate", "max"))
                 .round(3))
display(group_summary)

# Write one descriptive sentence and one causal claim the table does NOT support.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Run+explicit+validation+checks+and+export+the+clean+development+handoff.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Every+check+must+be+true+before+saving+because+Parts+3%E2%80%935+assume+this+file+is+trustworthy.%0A%0Achecks+%3D+%7B%0A++++%22event_id_unique%22%3A+clean%5B%22event_id%22%5D.is_unique%2C%0A++++%22target_observed%22%3A+clean%5B%22target_quality%22%5D.eq%28%22observed%22%29.all%28%29%2C%0A++++%22attendance_present%22%3A+clean%5B%22actual_attendance%22%5D.notna%28%29.all%28%29%2C%0A++++%22attendance_within_capacity%22%3A+clean%5B%22actual_attendance%22%5D.between%280%2C+clean%5B%22capacity%22%5D%29.all%28%29%2C%0A++++%22rate_matches%22%3A+%28%28clean%5B%22actual_attendance%22%5D+%2F+clean%5B%22capacity%22%5D%29.round%283%29+%3D%3D+clean%5B%22attendance_rate%22%5D%29.all%28%29%2C%0A++++%22target_matches%22%3A+%28clean%5B%22attendance_rate%22%5D.ge%280.65%29.map%28%7BTrue%3A+%22yes%22%2C+False%3A+%22no%22%7D%29+%3D%3D+clean%5B%22high_turnout%22%5D%29.all%28%29%2C%0A%7D%0Aprint%28checks%29%0Aassert+all%28checks.values%28%29%29%2C+%22Repair+failed+validation+checks+before+exporting.%22%0A%0Aclean.to_csv%28%22campus_events_development_clean.csv%22%2C+index%3DFalse%29%0Aprint%28%22Saved+campus_events_development_clean.csv%22%2C+clean.shape%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Run explicit validation checks and export the clean development handoff.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Every check must be true before saving because Parts 3–5 assume this file is trustworthy.

checks = {
    "event_id_unique": clean["event_id"].is_unique,
    "target_observed": clean["target_quality"].eq("observed").all(),
    "attendance_present": clean["actual_attendance"].notna().all(),
    "attendance_within_capacity": clean["actual_attendance"].between(0, clean["capacity"]).all(),
    "rate_matches": ((clean["actual_attendance"] / clean["capacity"]).round(3) == clean["attendance_rate"]).all(),
    "target_matches": (clean["attendance_rate"].ge(0.65).map({True: "yes", False: "no"}) == clean["high_turnout"]).all(),
}
print(checks)
assert all(checks.values()), "Repair failed validation checks before exporting."

clean.to_csv("campus_events_development_clean.csv", index=False)
print("Saved campus_events_development_clean.csv", clean.shape)

# %% [markdown]
# ---
#
# # Part 3 · Released reference solution from an earlier checkpoint
#
# Run this section in order. Earlier reference code creates the handoffs needed below.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Load+the+clean+Module+6+handoff+and+plotting+tools.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Verify+that+attendance_rate+and+the+other+analysis+columns+exist+before+calculating+statistics.%0A%0Aimport+pandas+as+pd%0Aimport+matplotlib.pyplot+as+plt%0Afrom+pathlib+import+Path%0A%0ADATA+%3D+Path%28%22campus_events_development_clean.csv%22%29%0Aif+not+DATA.exists%28%29%3A%0A++++raise+FileNotFoundError%28%22Upload+the+Module+6+handoff+or+supplied+recovery+file.%22%29%0Adf+%3D+pd.read_csv%28DATA%29%0Adf%5B%22high_turnout_flag%22%5D+%3D+df%5B%22high_turnout%22%5D.map%28%7B%22no%22%3A+0%2C+%22yes%22%3A+1%7D%29%0Aprint%28df.shape%29%0Adf.head%28%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Load the clean Module 6 handoff and plotting tools.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Verify that attendance_rate and the other analysis columns exist before calculating statistics.

import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA = Path("campus_events_development_clean.csv")
if not DATA.exists():
    raise FileNotFoundError("Upload the Module 6 handoff or supplied recovery file.")
df = pd.read_csv(DATA)
df["high_turnout_flag"] = df["high_turnout"].map({"no": 0, "yes": 1})
print(df.shape)
df.head()

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Calculate+center+and+spread+using+mean%2C+median%2C+mode%2C+range%2C+standard+deviation%2C+and+IQR.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Compare+measures+rather+than+reporting+one+number%3B+disagreement+can+reveal+skew+or+unusual+events.%0A%0Arate+%3D+df%5B%22attendance_rate%22%5D%0Asummary+%3D+%7B%0A++++%22mean%22%3A+rate.mean%28%29%2C%0A++++%22median%22%3A+rate.median%28%29%2C%0A++++%22mode%22%3A+rate.mode%28%29.tolist%28%29%2C%0A++++%22range%22%3A+rate.max%28%29+-+rate.min%28%29%2C%0A++++%22std%22%3A+rate.std%28%29%2C%0A++++%22iqr%22%3A+rate.quantile%28.75%29+-+rate.quantile%28.25%29%2C%0A++++%22min%22%3A+rate.min%28%29%2C%0A++++%22max%22%3A+rate.max%28%29%2C%0A%7D%0Aprint%28summary%29%0Aplt.figure%28figsize%3D%288%2C+4%29%29%0Aplt.hist%28rate%2C+bins%3D12%2C+color%3D%22%23A32638%22%2C+edgecolor%3D%22white%22%29%0Aplt.axvline%28rate.median%28%29%2C+color%3D%22black%22%2C+linestyle%3D%22--%22%2C+label%3D%22median%22%29%0Aplt.xlabel%28%22Attendance+rate%22%29%0Aplt.ylabel%28%22Number+of+development+events%22%29%0Aplt.title%28%22Development+data%3A+attendance-rate+distribution%22%29%0Aplt.legend%28%29%0Aplt.show%28%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Calculate center and spread using mean, median, mode, range, standard deviation, and IQR.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Compare measures rather than reporting one number; disagreement can reveal skew or unusual events.

rate = df["attendance_rate"]
summary = {
    "mean": rate.mean(),
    "median": rate.median(),
    "mode": rate.mode().tolist(),
    "range": rate.max() - rate.min(),
    "std": rate.std(),
    "iqr": rate.quantile(.75) - rate.quantile(.25),
    "min": rate.min(),
    "max": rate.max(),
}
print(summary)
plt.figure(figsize=(8, 4))
plt.hist(rate, bins=12, color="#A32638", edgecolor="white")
plt.axvline(rate.median(), color="black", linestyle="--", label="median")
plt.xlabel("Attendance rate")
plt.ylabel("Number of development events")
plt.title("Development data: attendance-rate distribution")
plt.legend()
plt.show()

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Use+the+IQR+rule+to+identify+potential+outliers+in+previous+similar+attendance.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Treat+the+flag+as+a+prompt+for+investigation%2C+not+automatic+permission+to+delete+a+valid+event.%0A%0Aoutlier_column+%3D+%22previous_similar_attendance%22%0Aq1+%3D+df%5Boutlier_column%5D.quantile%28.25%29%0Aq3+%3D+df%5Boutlier_column%5D.quantile%28.75%29%0Aiqr+%3D+q3+-+q1%0Alower%2C+upper+%3D+q1+-+1.5+%2A+iqr%2C+q3+%2B+1.5+%2A+iqr%0Aflagged+%3D+df%5B~df%5Boutlier_column%5D.between%28lower%2C+upper%29%5D%0Aprint%28%22IQR+fences%3A%22%2C+round%28lower%2C+1%29%2C+%22to%22%2C+round%28upper%2C+1%29%29%0Aprint%28%22Flagged+rows%3A%22%2C+len%28flagged%29%29%0Adisplay%28flagged%5B%5B%22event_id%22%2C+%22event_type%22%2C+outlier_column%2C+%22capacity%22%5D%5D.head%2810%29%29%0A%0Aevent_means+%3D+df.groupby%28%22event_type%22%29%5B%22attendance_rate%22%5D.mean%28%29.sort_values%28%29%0Afig%2C+axes+%3D+plt.subplots%281%2C+2%2C+figsize%3D%2812%2C+4%29%29%0Aevent_means.plot.bar%28ax%3Daxes%5B0%5D%2C+color%3D%22%23A32638%22%29%0Aaxes%5B0%5D.set_ylim%28max%280%2C+event_means.min%28%29+-+.03%29%2C+event_means.max%28%29+%2B+.03%29%0Aaxes%5B0%5D.set_title%28%22Cropped+axis%3A+differences+look+large%22%29%0Aevent_means.plot.bar%28ax%3Daxes%5B1%5D%2C+color%3D%22%23315F86%22%29%0Aaxes%5B1%5D.set_ylim%280%2C+1%29%0Aaxes%5B1%5D.set_title%28%22Full+attendance-rate+scale%22%29%0Afor+axis+in+axes%3A%0A++++axis.set_ylabel%28%22Mean+attendance+rate%22%29%0Aplt.tight_layout%28%29%0Aplt.show%28%29%0A%0A%23+Explain+why+a+full+scale+and+visible+labels+matter."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Use the IQR rule to identify potential outliers in previous similar attendance.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Treat the flag as a prompt for investigation, not automatic permission to delete a valid event.

outlier_column = "previous_similar_attendance"
q1 = df[outlier_column].quantile(.25)
q3 = df[outlier_column].quantile(.75)
iqr = q3 - q1
lower, upper = q1 - 1.5 * iqr, q3 + 1.5 * iqr
flagged = df[~df[outlier_column].between(lower, upper)]
print("IQR fences:", round(lower, 1), "to", round(upper, 1))
print("Flagged rows:", len(flagged))
display(flagged[["event_id", "event_type", outlier_column, "capacity"]].head(10))

event_means = df.groupby("event_type")["attendance_rate"].mean().sort_values()
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
event_means.plot.bar(ax=axes[0], color="#A32638")
axes[0].set_ylim(max(0, event_means.min() - .03), event_means.max() + .03)
axes[0].set_title("Cropped axis: differences look large")
event_means.plot.bar(ax=axes[1], color="#315F86")
axes[1].set_ylim(0, 1)
axes[1].set_title("Full attendance-rate scale")
for axis in axes:
    axis.set_ylabel("Mean attendance rate")
plt.tight_layout()
plt.show()

# Explain why a full scale and visible labels matter.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Summarize+turnout+by+event+type+and+compare+full-axis+with+cropped-axis+charts.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Notice+how+axis+choices+alter+visual+emphasis+even+when+the+underlying+values+remain+identical.%0A%0Agroup_report+%3D+%28df.groupby%28%22event_type%22%29%0A++++++++++++++++++.agg%28events%3D%28%22event_id%22%2C+%22size%22%29%2C%0A+++++++++++++++++++++++median_attendance_rate%3D%28%22attendance_rate%22%2C+%22median%22%29%2C%0A+++++++++++++++++++++++high_turnout_rate%3D%28%22high_turnout_flag%22%2C+%22mean%22%29%29%0A++++++++++++++++++.sort_values%28%22high_turnout_rate%22%2C+ascending%3DFalse%29%29%0Adisplay%28group_report.round%283%29%29%0A%0Apre_event_numeric+%3D+%5B%22capacity%22%2C+%22start_hour%22%2C+%22ticket_price_usd%22%2C+%22promotion_days%22%2C%0A+++++++++++++++++++++%22social_posts%22%2C+%22poster_count%22%2C+%22previous_similar_attendance%22%2C%0A+++++++++++++++++++++%22competing_events%22%5D%0Aassociations+%3D+%28df%5Bpre_event_numeric+%2B+%5B%22high_turnout_flag%22%5D%5D%0A++++++++++++++++.corr%28numeric_only%3DTrue%29%5B%22high_turnout_flag%22%5D%0A++++++++++++++++.drop%28%22high_turnout_flag%22%29%0A++++++++++++++++.sort_values%28key%3Dabs%2C+ascending%3DFalse%29%29%0Adisplay%28associations.round%283%29%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Summarize turnout by event type and compare full-axis with cropped-axis charts.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Notice how axis choices alter visual emphasis even when the underlying values remain identical.

group_report = (df.groupby("event_type")
                  .agg(events=("event_id", "size"),
                       median_attendance_rate=("attendance_rate", "median"),
                       high_turnout_rate=("high_turnout_flag", "mean"))
                  .sort_values("high_turnout_rate", ascending=False))
display(group_report.round(3))

pre_event_numeric = ["capacity", "start_hour", "ticket_price_usd", "promotion_days",
                     "social_posts", "poster_count", "previous_similar_attendance",
                     "competing_events"]
associations = (df[pre_event_numeric + ["high_turnout_flag"]]
                .corr(numeric_only=True)["high_turnout_flag"]
                .drop("high_turnout_flag")
                .sort_values(key=abs, ascending=False))
display(associations.round(3))

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Create+a+scatter+plot+and+correlation+while+explicitly+considering+lurking+variables.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Describe+association+cautiously%3A+correlation+alone+does+not+prove+that+one+feature+causes+turnout.%0A%0Ax_column+%3D+%22previous_similar_attendance%22%0Ay_column+%3D+%22attendance_rate%22%0Acorrelation+%3D+df%5B%5Bx_column%2C+y_column%5D%5D.corr%28%29.iloc%5B0%2C+1%5D%0Aplt.figure%28figsize%3D%287%2C+5%29%29%0Aplt.scatter%28df%5Bx_column%5D%2C+df%5By_column%5D%2C+alpha%3D.65%2C+color%3D%22%23A32638%22%29%0Aplt.xlabel%28%22Previous+similar-event+attendance%22%29%0Aplt.ylabel%28%22Current+attendance+rate%22%29%0Aplt.title%28f%22Development+association+%28r+%3D+%7Bcorrelation%3A.2f%7D%29%22%29%0Aplt.show%28%29%0A%0Alurking_variable_questions+%3D+%5B%0A++++%22Could+venue+capacity+affect+both+previous+attendance+and+current+attendance+rate%3F%22%2C%0A++++%22Could+organizer+resources+affect+both+promotion+and+turnout%3F%22%2C%0A++++%22Could+event+type+create+groups+with+different+patterns%3F%22%2C%0A%5D%0Aprint%28%22%5Cn%22.join%28f%22-+%7Bquestion%7D%22+for+question+in+lurking_variable_questions%29%29%0A%0A%23+Write+one+correlation+sentence%2C+one+non-causal+limitation%2C+and+one+next+check."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Create a scatter plot and correlation while explicitly considering lurking variables.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Describe association cautiously: correlation alone does not prove that one feature causes turnout.

x_column = "previous_similar_attendance"
y_column = "attendance_rate"
correlation = df[[x_column, y_column]].corr().iloc[0, 1]
plt.figure(figsize=(7, 5))
plt.scatter(df[x_column], df[y_column], alpha=.65, color="#A32638")
plt.xlabel("Previous similar-event attendance")
plt.ylabel("Current attendance rate")
plt.title(f"Development association (r = {correlation:.2f})")
plt.show()

lurking_variable_questions = [
    "Could venue capacity affect both previous attendance and current attendance rate?",
    "Could organizer resources affect both promotion and turnout?",
    "Could event type create groups with different patterns?",
]
print("\n".join(f"- {question}" for question in lurking_variable_questions))

# Write one correlation sentence, one non-causal limitation, and one next check.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Create+the+feature-review+handoff+for+Module+8.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Include+availability%2C+leakage%2C+ethics%2C+and+evidence%E2%80%94not+just+statistical+strength%E2%80%94before+recommending+a+feature.%0A%0AREQUIRED_COLUMNS+%3D+%5B%0A++++%22candidate_feature%22%2C+%22m7_evidence%22%2C+%22available_before_prediction%22%2C%0A++++%22direct_leakage%22%2C+%22identifier%22%2C+%22proxy_risk%22%2C+%22decision%22%2C+%22reason%22%0A%5D%0Afeature_review+%3D+pd.DataFrame%28%5B%0A++++%5B%22capacity%22%2C+%22Group+sizes+and+distributions+reviewed%22%2C+%22yes%22%2C+%22no%22%2C+%22no%22%2C+%22review%22%2C+%22accept%22%2C+%22Available+before+the+event%3B+test+generalization%22%5D%2C%0A++++%5B%22event_type%22%2C+%22Group+comparison+suggested+differences%22%2C+%22yes%22%2C+%22no%22%2C+%22no%22%2C+%22review%22%2C+%22accept%22%2C+%22Plausible+planning+context%3B+monitor+sparse+categories%22%5D%2C%0A++++%5B%22start_hour%22%2C+%22Schedule+patterns+reviewed%22%2C+%22yes%22%2C+%22no%22%2C+%22no%22%2C+%22low%22%2C+%22accept%22%2C+%22Known+before+the+event%22%5D%2C%0A++++%5B%22day_of_week%22%2C+%22Schedule+patterns+reviewed%22%2C+%22yes%22%2C+%22no%22%2C+%22no%22%2C+%22low%22%2C+%22accept%22%2C+%22Known+before+the+event%22%5D%2C%0A++++%5B%22weather_forecast%22%2C+%22Forecast+context+reviewed%22%2C+%22yes%22%2C+%22no%22%2C+%22no%22%2C+%22low%22%2C+%22accept%22%2C+%22Forecast+is+available+before+the+event%22%5D%2C%0A++++%5B%22promotion_days%22%2C+%22Association+reviewed+without+causal+claim%22%2C+%22yes%22%2C+%22no%22%2C+%22no%22%2C+%22review%22%2C+%22accept%22%2C+%22Available+before+the+event%22%5D%2C%0A++++%5B%22social_posts%22%2C+%22Association+reviewed+without+causal+claim%22%2C+%22yes%22%2C+%22no%22%2C+%22no%22%2C+%22review%22%2C+%22accept%22%2C+%22Available+before+the+event%3B+may+reflect+resource+differences%22%5D%2C%0A++++%5B%22event_id%22%2C+%22Unique+record+label%3B+no+generalizable+evidence%22%2C+%22yes%22%2C+%22no%22%2C+%22yes%22%2C+%22high%22%2C+%22reject%22%2C+%22Identifier+rather+than+a+planning+clue%22%5D%2C%0A++++%5B%22actual_attendance%22%2C+%22Directly+determines+the+target%22%2C+%22no%22%2C+%22yes%22%2C+%22no%22%2C+%22high%22%2C+%22reject%22%2C+%22Post-event+leakage%22%5D%2C%0A%5D%2C+columns%3DREQUIRED_COLUMNS%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Create the feature-review handoff for Module 8.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Include availability, leakage, ethics, and evidence—not just statistical strength—before recommending a feature.

REQUIRED_COLUMNS = [
    "candidate_feature", "m7_evidence", "available_before_prediction",
    "direct_leakage", "identifier", "proxy_risk", "decision", "reason"
]
feature_review = pd.DataFrame([
    ["capacity", "Group sizes and distributions reviewed", "yes", "no", "no", "review", "accept", "Available before the event; test generalization"],
    ["event_type", "Group comparison suggested differences", "yes", "no", "no", "review", "accept", "Plausible planning context; monitor sparse categories"],
    ["start_hour", "Schedule patterns reviewed", "yes", "no", "no", "low", "accept", "Known before the event"],
    ["day_of_week", "Schedule patterns reviewed", "yes", "no", "no", "low", "accept", "Known before the event"],
    ["weather_forecast", "Forecast context reviewed", "yes", "no", "no", "low", "accept", "Forecast is available before the event"],
    ["promotion_days", "Association reviewed without causal claim", "yes", "no", "no", "review", "accept", "Available before the event"],
    ["social_posts", "Association reviewed without causal claim", "yes", "no", "no", "review", "accept", "Available before the event; may reflect resource differences"],
    ["event_id", "Unique record label; no generalizable evidence", "yes", "no", "yes", "high", "reject", "Identifier rather than a planning clue"],
    ["actual_attendance", "Directly determines the target", "no", "yes", "no", "high", "reject", "Post-event leakage"],
], columns=REQUIRED_COLUMNS)

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Validate+the+completed+feature-review+schema+and+export+it.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Resolve+every+missing+column+or+unfinished+decision+before+saving+because+Module+8+reads+this+file+as+its+planning+evidence.%0A%0Amissing_columns+%3D+%5Bc+for+c+in+REQUIRED_COLUMNS+if+c+not+in+feature_review.columns%5D%0Aassert+not+missing_columns%2C+f%22Missing+columns%3A+%7Bmissing_columns%7D%22%0Aassert+len%28feature_review%29+%3E%3D+8%2C+%22Review+at+least+eight+candidate+features.%22%0Aassert+feature_review%5B%22decision%22%5D.isin%28%5B%22accept%22%2C+%22reject%22%5D%29.all%28%29%0Aassert+feature_review%5BREQUIRED_COLUMNS%5D.astype%28str%29.apply%28lambda+s%3A+s.str.strip%28%29.ne%28%22%22%29%29.all%28%29.all%28%29%0Aassert+feature_review%5B%22decision%22%5D.eq%28%22accept%22%29.sum%28%29+%3E%3D+2%0Aassert+feature_review%5B%22decision%22%5D.eq%28%22reject%22%29.sum%28%29+%3E%3D+2%0A%0Afeature_review.to_csv%28%22m7_feature_review.csv%22%2C+index%3DFalse%29%0Aprint%28%22Saved+m7_feature_review.csv%22%29%0Adisplay%28feature_review%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Validate the completed feature-review schema and export it.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Resolve every missing column or unfinished decision before saving because Module 8 reads this file as its planning evidence.

missing_columns = [c for c in REQUIRED_COLUMNS if c not in feature_review.columns]
assert not missing_columns, f"Missing columns: {missing_columns}"
assert len(feature_review) >= 8, "Review at least eight candidate features."
assert feature_review["decision"].isin(["accept", "reject"]).all()
assert feature_review[REQUIRED_COLUMNS].astype(str).apply(lambda s: s.str.strip().ne("")).all().all()
assert feature_review["decision"].eq("accept").sum() >= 2
assert feature_review["decision"].eq("reject").sum() >= 2

feature_review.to_csv("m7_feature_review.csv", index=False)
print("Saved m7_feature_review.csv")
display(feature_review)

# %% [markdown]
# ---
#
# # Part 4 · Your current work for Module 8
#
# Run this section in order. Earlier reference code creates the handoffs needed below.

# %% [markdown]
# # Will They Show Up? · Checkpoint 4
# ## Lock the Model Blueprint
#
# **Module 8 contribution:** Audit the feature handoff, define the target and evaluation plan, establish a development baseline, and freeze the decisions Module 9 must follow.
#
# **Driving question:** What must be decided before training so the final score is interpretable?

# %% [markdown]
# ## Place this project on the machine-learning map
#
# - **Supervised learning:** learns from labeled examples. This project belongs here.
# - **Unsupervised learning:** looks for structure without a supplied target.
# - **Reinforcement learning:** learns from rewards after actions.
# - **Generative AI:** creates new content from learned patterns.
#
# For this supervised classification task, each row is an example, accepted pre-event columns are features, and `high_turnout` is the target.

# %% [markdown]
# <details>
# <summary><strong>Reveal model answer</strong></summary>
#
# Use this to check your reasoning after you have written your own response.
#
# **Reference answer:** This is
# supervised classification because historical rows contain known `high_turnout` labels. The
# accepted pre-event columns are features, `high_turnout` is the target, the trained pipeline is
# the model, its output is a predicted class, and an error occurs when prediction and known
# target disagree.
#
# </details>

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Load+the+clean+development+data%2C+Module+7+feature+review%2C+and+JSON+support.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+These+are+the+evidence+sources+for+the+model+blueprint%3B+do+not+consult+the+sealed+final+holdout.%0A%0Aimport+json%0Afrom+pathlib+import+Path%0Aimport+pandas+as+pd%0Afrom+sklearn.model_selection+import+train_test_split%0A%0ADATA+%3D+Path%28%22campus_events_development_clean.csv%22%29%0AREVIEW+%3D+Path%28%22m7_feature_review.csv%22%29%0Aif+not+DATA.exists%28%29+or+not+REVIEW.exists%28%29%3A%0A++++raise+FileNotFoundError%28%22Upload+the+M6+clean+development+data+and+M7+feature+review%2C+or+recovery+copies.%22%29%0Adf+%3D+pd.read_csv%28DATA%29%0Afeature_review+%3D+pd.read_csv%28REVIEW%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Load the clean development data, Module 7 feature review, and JSON support.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: These are the evidence sources for the model blueprint; do not consult the sealed final holdout.

import json
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split

DATA = Path("campus_events_development_clean.csv")
REVIEW = Path("m7_feature_review.csv")
if not DATA.exists() or not REVIEW.exists():
    raise FileNotFoundError("Upload the M6 clean development data and M7 feature review, or recovery copies.")
df = pd.read_csv(DATA)
feature_review = pd.read_csv(REVIEW)

# %% [markdown]
# ## Validate the handoff—never repair required evidence silently

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Validate+the+structure+of+the+feature-review+table.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Stop+on+missing+required+columns+because+an+incomplete+review+would+weaken+every+later+feature+decision.%0A%0AREQUIRED_COLUMNS+%3D+%5B%0A++++%22candidate_feature%22%2C+%22m7_evidence%22%2C+%22available_before_prediction%22%2C%0A++++%22direct_leakage%22%2C+%22identifier%22%2C+%22proxy_risk%22%2C+%22decision%22%2C+%22reason%22%0A%5D%0Amissing+%3D+%5Bc+for+c+in+REQUIRED_COLUMNS+if+c+not+in+feature_review.columns%5D%0Aif+missing%3A%0A++++raise+ValueError%28f%22M7+handoff+uses+the+wrong+schema.+Missing%3A+%7Bmissing%7D%22%29%0Aif+feature_review%5BREQUIRED_COLUMNS%5D.isna%28%29.any%28%29.any%28%29%3A%0A++++raise+ValueError%28%22Complete+every+required+feature-review+field.%22%29%0A%0Aaccepted+%3D+feature_review.loc%5Bfeature_review%5B%22decision%22%5D.str.lower%28%29.eq%28%22accept%22%29%2C+%22candidate_feature%22%5D.tolist%28%29%0Arejected+%3D+feature_review.loc%5B~feature_review%5B%22decision%22%5D.str.lower%28%29.eq%28%22accept%22%29%5D.to_dict%28%22records%22%29%0Aif+not+accepted%3A%0A++++raise+ValueError%28%22Accept+at+least+one+justified+pre-event+feature+before+exporting+a+blueprint.%22%29%0A%0Ablocked+%3D+%7B%22event_id%22%2C+%22actual_weather%22%2C+%22actual_attendance%22%2C+%22attendance_rate%22%2C+%22high_turnout%22%2C+%22high_turnout_flag%22%7D%0Aif+blocked.intersection%28accepted%29%3A%0A++++raise+ValueError%28f%22Blocked+feature+accepted%3A+%7Bblocked.intersection%28accepted%29%7D%22%29%0Aunknown+%3D+%5Bc+for+c+in+accepted+if+c+not+in+df.columns%5D%0Aif+unknown%3A%0A++++raise+ValueError%28f%22Accepted+features+missing+from+data%3A+%7Bunknown%7D%22%29%0Aprint%28%22Accepted%3A%22%2C+accepted%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Validate the structure of the feature-review table.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Stop on missing required columns because an incomplete review would weaken every later feature decision.

REQUIRED_COLUMNS = [
    "candidate_feature", "m7_evidence", "available_before_prediction",
    "direct_leakage", "identifier", "proxy_risk", "decision", "reason"
]
missing = [c for c in REQUIRED_COLUMNS if c not in feature_review.columns]
if missing:
    raise ValueError(f"M7 handoff uses the wrong schema. Missing: {missing}")
if feature_review[REQUIRED_COLUMNS].isna().any().any():
    raise ValueError("Complete every required feature-review field.")

accepted = feature_review.loc[feature_review["decision"].str.lower().eq("accept"), "candidate_feature"].tolist()
rejected = feature_review.loc[~feature_review["decision"].str.lower().eq("accept")].to_dict("records")
if not accepted:
    raise ValueError("Accept at least one justified pre-event feature before exporting a blueprint.")

blocked = {"event_id", "actual_weather", "actual_attendance", "attendance_rate", "high_turnout", "high_turnout_flag"}
if blocked.intersection(accepted):
    raise ValueError(f"Blocked feature accepted: {blocked.intersection(accepted)}")
unknown = [c for c in accepted if c not in df.columns]
if unknown:
    raise ValueError(f"Accepted features missing from data: {unknown}")
print("Accepted:", accepted)

# %% [markdown]
# ## Explain features, target, model, prediction, and error
#
# Select one development row and identify its input features and known target. The model will learn a mapping from features to a predicted label. Error is the disagreement between that prediction and the known target.

# %% [markdown]
# <details>
# <summary><strong>Reveal model answer</strong></summary>
#
# Use this to check your reasoning after you have written your own response.
#
# **Reference answer:** One
# row supplies the accepted pre-event feature values. The known yes/no `high_turnout` value is
# the target used during learning and evaluation. The model maps feature patterns to a predicted
# label; comparing that label with the known target reveals whether that example was correct.
#
# </details>

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Print+one+concrete+row+using+the+proposed+feature+names.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+Use+this+trace+to+explain+in+plain+language+what+information+the+model+would+actually+receive.%0A%0Aexample+%3D+df.iloc%5B0%5D%0Aprint%28%22Feature+values%3A%22%29%0Aprint%28example%5Baccepted%5D.to_dict%28%29%29%0Aprint%28%22Known+training+target%3A%22%2C+example%5B%22high_turnout%22%5D%29%0A%0A%23+Explain+why+the+target+cannot+also+appear+in+accepted+features."><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Print one concrete row using the proposed feature names.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Use this trace to explain in plain language what information the model would actually receive.

example = df.iloc[0]
print("Feature values:")
print(example[accepted].to_dict())
print("Known training target:", example["high_turnout"])

# Explain why the target cannot also appear in accepted features.

# %% [markdown]
# ## Plan model development
#
# The separate final holdout is not present in this module. Split the development data into training and validation only. Validation will select the model in M9.

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Define+the+target%2C+map+yes%2Fno+labels+to+numbers%2C+inspect+class+balance%2C+and+create+a+development+split.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+The+validation+subset+estimates+generalization%3B+it+must+remain+separate+from+model+fitting.%0A%0Atarget+%3D+%22high_turnout%22%0Ay+%3D+df%5Btarget%5D.map%28%7B%22no%22%3A+0%2C+%22yes%22%3A+1%7D%29%0Atrain_index%2C+validation_index+%3D+train_test_split%28%0A++++df.index%2C+test_size%3D0.25%2C+random_state%3D42%2C+stratify%3Dy%0A%29%0Ay_train+%3D+y.loc%5Btrain_index%5D%0Ay_validation+%3D+y.loc%5Bvalidation_index%5D%0Abaseline_label+%3D+int%28y_train.mode%28%29.iloc%5B0%5D%29%0Avalidation_baseline+%3D+float%28%28y_validation+%3D%3D+baseline_label%29.mean%28%29%29%0Aprint%28%22Train+rows%3A%22%2C+len%28train_index%29%2C+%22Validation+rows%3A%22%2C+len%28validation_index%29%29%0Aprint%28%22Full+class+balance%3A%22%29%0Aprint%28y.value_counts%28normalize%3DTrue%29.sort_index%28%29.round%283%29%29%0Aprint%28%22Validation+majority+baseline%3A%22%2C+round%28validation_baseline%2C+3%29%29"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Define the target, map yes/no labels to numbers, inspect class balance, and create a development split.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: The validation subset estimates generalization; it must remain separate from model fitting.

target = "high_turnout"
y = df[target].map({"no": 0, "yes": 1})
train_index, validation_index = train_test_split(
    df.index, test_size=0.25, random_state=42, stratify=y
)
y_train = y.loc[train_index]
y_validation = y.loc[validation_index]
baseline_label = int(y_train.mode().iloc[0])
validation_baseline = float((y_validation == baseline_label).mean())
print("Train rows:", len(train_index), "Validation rows:", len(validation_index))
print("Full class balance:")
print(y.value_counts(normalize=True).sort_index().round(3))
print("Validation majority baseline:", round(validation_baseline, 3))

# %% [markdown]
# ## Plan the fit check before training
#
# Underfitting means the model is too simple to capture a useful pattern. Overfitting means it performs much better on training examples than on validation examples. A useful model must be compared on both—not judged from training accuracy alone.

# %% [markdown]
# <details>
# <summary><strong>Reveal model answer</strong></summary>
#
# Use this to check your reasoning after you have written your own response.
#
# **Reference answer:** Compare training and
# validation performance. Low performance on both suggests underfitting. Much stronger training
# than validation performance suggests overfitting. Similar, useful performance on both is more
# consistent with generalization, though the sealed holdout is still required for final evidence.
#
# </details>

# %%
# TASK: List candidate algorithms and explain their learning behavior and tradeoffs.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: The goal is a justified comparison plan, not choosing an algorithm merely because it sounds advanced.

candidate_algorithms = [
    # TODO: Add logistic_regression and decision_tree.
    # Explain what different pattern each can learn and one fit risk.
]
fit_diagnosis_plan = {
    "underfitting_signal": "both training and validation performance remain weak",
    "overfitting_signal": "training performance is much stronger than validation performance",
    "next_checks": ["compare with the majority baseline", "inspect class-specific errors", "review feature leakage", "test simpler and more constrained settings"],
}
if len(candidate_algorithms) < 2:
    raise ValueError("Plan at least two candidate algorithms before exporting.")
candidate_algorithms, fit_diagnosis_plan

# %% [markdown]
# <details>
# <summary><strong>Reveal reference solution</strong></summary>
#
# Use this after making a genuine attempt. Compare the approach with your own work;
# more than one correct solution may exist.
#
# ```python
# # TASK: List candidate algorithms and explain their learning behavior and tradeoffs.
# # WHY: This code creates evidence used by this checkpoint and the next project stage.
# # CHECK: The goal is a justified comparison plan, not choosing an algorithm merely because it sounds advanced.
#
# candidate_algorithms = [
#     {"name": "logistic_regression", "why": "interpretable linear probability pattern and a useful baseline model"},
#     {"name": "decision_tree", "why": "nonlinear split rules that are easy to visualize but can overfit"},
# ]
# fit_diagnosis_plan = {
#     "underfitting_signal": "both training and validation performance remain weak",
#     "overfitting_signal": "training performance is much stronger than validation performance",
#     "next_checks": ["compare with the majority baseline", "inspect class-specific errors", "review feature leakage", "test simpler and more constrained settings"],
# }
# if len(candidate_algorithms) < 2:
#     raise ValueError("Plan at least two candidate algorithms before exporting.")
# candidate_algorithms, fit_diagnosis_plan
# ```
#
# </details>

# %% [markdown]
# ## Name success, error costs, failure cases, and boundaries

# %% [markdown]
# <details>
# <summary><strong>Reveal model answer</strong></summary>
#
# Use this to check your reasoning after you have written your own response.
#
# **Reference answer:**
# Success means improving on the majority baseline while examining precision, recall, F1, and
# the confusion matrix. A false positive may waste preparation; a false negative may underprepare
# for strong turnout. The relative cost is a human value judgment. Prohibit real funding,
# disciplinary, access, or fully automated decisions from this synthetic classroom model.
#
# </details>

# %%
# TASK: State the primary evaluation view and the relative cost of false positives and false negatives.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: Connect metric choices to the practical planning consequences of the two error types.

primary_metric = "accuracy, interpreted with precision, recall, and the confusion matrix"
more_costly_error = ""  # TODO: state which error matters more and why
predicted_failure_cases = [
    "an unfamiliar event category",
    "promotion practices change after development data were collected",
    "a forecast changes after the prediction",
]
prohibited_uses = [
    "denying access to events",
    "making funding or staffing decisions without human review",
    "applying this synthetic classroom model to real people or institutions",
]
if not more_costly_error.strip():
    raise ValueError("Complete the error-cost judgment before exporting.")

# %% [markdown]
# <details>
# <summary><strong>Reveal reference solution</strong></summary>
#
# Use this after making a genuine attempt. Compare the approach with your own work;
# more than one correct solution may exist.
#
# ```python
# # TASK: State the primary evaluation view and the relative cost of false positives and false negatives.
# # WHY: This code creates evidence used by this checkpoint and the next project stage.
# # CHECK: Connect metric choices to the practical planning consequences of the two error types.
#
# primary_metric = "accuracy, interpreted with precision, recall, and the confusion matrix"
# more_costly_error = "false negatives may underprepare a strong event; human planners decide the real priority"
# predicted_failure_cases = [
#     "an unfamiliar event category",
#     "promotion practices change after development data were collected",
#     "a forecast changes after the prediction",
# ]
# prohibited_uses = [
#     "denying access to events",
#     "making funding or staffing decisions without human review",
#     "applying this synthetic classroom model to real people or institutions",
# ]
# if not more_costly_error.strip():
#     raise ValueError("Complete the error-cost judgment before exporting.")
# ```
#
# </details>

# %% [markdown]
# ## Export the locked blueprint

# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; border-left:4px solid #999; border-radius:6px; background:rgba(153,153,153,0.08); padding:8px 20px 8px 16px; margin:6px 0;">
#   <span>&#128269;&nbsp;<b>Stuck on this code?</b></span>
#   <span style="display:flex; align-items:center; gap:8px;">
#     <a href="VIDEO_LINK_HERE"><img src="https://img.shields.io/badge/Watch_Video-red?style=flat&amp;logo=youtube&amp;logoColor=white" alt="Watch the video" style="height:26px; vertical-align:middle;"></a>
#     <a href="https://chatgpt.com/?q=Explain+what+this+Python+code+does%2C+step+by+step%2C+in+simple+beginner-friendly+terms.+Do+not+just+repeat+the+code+back+to+me%3B+explain+the+%2Awhy%2A+behind+each+line.%0A%0A%23+TASK%3A+Lock+and+export+the+model+blueprint+before+final+evaluation.%0A%23+WHY%3A+This+code+creates+evidence+used+by+this+checkpoint+and+the+next+project+stage.%0A%23+CHECK%3A+The+saved+JSON+records+features%2C+target%2C+split%2C+metrics%2C+safeguards%2C+and+limits+so+M9+cannot+rewrite+the+plan+after+seeing+results.%0A%0Ablueprint+%3D+%7B%0A++++%22project%22%3A+%22Will+They+Show+Up%3F%22%2C%0A++++%22target%22%3A+target%2C%0A++++%22accepted_features%22%3A+accepted%2C%0A++++%22rejected_features%22%3A+rejected%2C%0A++++%22development_split%22%3A+%7B%0A++++++++%22method%22%3A+%22stratified+train%2Fvalidation%22%2C%0A++++++++%22validation_fraction%22%3A+0.25%2C%0A++++++++%22random_state%22%3A+42%2C%0A++++%7D%2C%0A++++%22validation_majority_baseline%22%3A+round%28validation_baseline%2C+3%29%2C%0A++++%22primary_metric%22%3A+primary_metric%2C%0A++++%22candidate_algorithms%22%3A+candidate_algorithms%2C%0A++++%22fit_diagnosis_plan%22%3A+fit_diagnosis_plan%2C%0A++++%22more_costly_error%22%3A+more_costly_error%2C%0A++++%22predicted_failure_cases%22%3A+predicted_failure_cases%2C%0A++++%22prohibited_uses%22%3A+prohibited_uses%2C%0A++++%22final_holdout_rule%22%3A+%22Introduced+in+M9%3B+use+once+after+model+selection.%22%2C%0A%7D%0APath%28%22m8_model_blueprint.json%22%29.write_text%28json.dumps%28blueprint%2C+indent%3D2%29%29%0Aprint%28%22Saved+m8_model_blueprint.json%22%29%0Ablueprint"><img src="https://img.shields.io/badge/%F0%9F%A4%96_Explain_with_ChatGPT-10a37f?style=flat" alt="Explain with ChatGPT" style="height:26px; vertical-align:middle;"></a>
#   </span>
# </div>

# %%
# TASK: Lock and export the model blueprint before final evaluation.
# WHY: This code creates evidence used by this checkpoint and the next project stage.
# CHECK: The saved JSON records features, target, split, metrics, safeguards, and limits so M9 cannot rewrite the plan after seeing results.

blueprint = {
    "project": "Will They Show Up?",
    "target": target,
    "accepted_features": accepted,
    "rejected_features": rejected,
    "development_split": {
        "method": "stratified train/validation",
        "validation_fraction": 0.25,
        "random_state": 42,
    },
    "validation_majority_baseline": round(validation_baseline, 3),
    "primary_metric": primary_metric,
    "candidate_algorithms": candidate_algorithms,
    "fit_diagnosis_plan": fit_diagnosis_plan,
    "more_costly_error": more_costly_error,
    "predicted_failure_cases": predicted_failure_cases,
    "prohibited_uses": prohibited_uses,
    "final_holdout_rule": "Introduced in M9; use once after model selection.",
}
Path("m8_model_blueprint.json").write_text(json.dumps(blueprint, indent=2))
print("Saved m8_model_blueprint.json")
blueprint

# %% [markdown]
# ## Gemini checkpoint and handoff
#
# Ask Gemini to look for leakage, missing evaluation decisions, or overclaims. Verify every suggestion against the feature table and project rules.
#
# Record what you accepted, rejected, or revised.
#
# **Handoff:** `m8_model_blueprint.json` goes to Module 9. Do not revise it after seeing final holdout performance.
